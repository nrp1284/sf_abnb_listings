# %%
# %matplotlib inline

# import dependencies
import pandas as pd
import numpy as np
import json
import geopandas as gpd

# %%
df = gpd.read_file('./resources/san-francisco.geojson')

df.head(10)
# Out:
#    OBJECTID    DISTRICT COMPANY  \
# 0         1     CENTRAL       A
# 1         2    SOUTHERN       B
# 2         3     BAYVIEW       C
# 3         4     MISSION       D
# 4         5        PARK       F
# 5         6    RICHMOND       G
# 6         7   INGLESIDE       H
# 7         8     TARAVAL       I
# 8         9    NORTHERN       E
# 9        10  TENDERLOIN       J
#
#                                             geometry
# 0  POLYGON ((-122.40532 37.80687, -122.40440 37.8...
# 1  MULTIPOLYGON (((-122.38822 37.79000, -122.3880...
# 2  POLYGON ((-122.39342 37.70841, -122.39349 37.7...
# 3  POLYGON ((-122.40802 37.76940, -122.40767 37.7...
# 4  POLYGON ((-122.44665 37.77588, -122.44683 37.7...
# 5  POLYGON ((-122.44805 37.78237, -122.44804 37.7...
# 6  POLYGON ((-122.40830 37.70833, -122.41009 37.7...
# 7  POLYGON ((-122.45552 37.71099, -122.45560 37.7...
# 8  POLYGON ((-122.44565 37.80537, -122.44399 37.8...
# 9  POLYGON ((-122.41795 37.78602, -122.41654 37.7...

# %%
df = df.drop(['OBJECTID', 'COMPANY'], axis=1)
df.head()
# Out:
#    DISTRICT                                           geometry
# 0   CENTRAL  POLYGON ((-122.40532 37.80687, -122.40440 37.8...
# 1  SOUTHERN  MULTIPOLYGON (((-122.38822 37.79000, -122.3880...
# 2   BAYVIEW  POLYGON ((-122.39342 37.70841, -122.39349 37.7...
# 3   MISSION  POLYGON ((-122.40802 37.76940, -122.40767 37.7...
# 4      PARK  POLYGON ((-122.44665 37.77588, -122.44683 37.7...

# %%
df.to_csv('./resources/sanfranciscogeo.csv')
