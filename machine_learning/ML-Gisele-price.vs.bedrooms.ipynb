# %%
# %matplotlib inline

# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import hvplot.pandas
from pathlib import Path
import plotly.express as px
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_blobs

# %%
# Load the dataset.
file_path = "./resources/listings_cleaned2_Modified.csv"
ab21_df = pd.read_csv(file_path,index_col=0)
ab21_df.head(5)
# Out:
#      host_since  host_response_time host_response_rate  host_is_superhost  \
# id
# 958   7/31/2008  within a few hours               100%                  1
# 7918  6/17/2009  within a few hours               100%                  0
# 8142  6/17/2009  within a few hours               100%                  0
# 8339   7/2/2009      within an hour               100%                  0
# 8739  1/27/2009      within an hour               100%                  1
#
#       host_listings_count  host_total_listings_count  host_identity_verified  \
# id
# 958                     1                          1                       1
# 7918                   10                         10                       1
# 8142                   10                         10                       1
# 8339                    2                          2                       1
# 8739                    2                          2                       0
#
#      neighbourhood_cleansed  zipcode  latitude  ...  review_scores_value  \
# id                                              ...
# 958        Western Addition    94115  37.76931  ...                  9.0
# 7918         Haight Ashbury    94117  37.76669  ...                  8.0
# 8142         Haight Ashbury    94117  37.76487  ...                  9.0
# 8339       Western Addition    94115  37.77525  ...                  9.0
# 8739                Mission    94110  37.75919  ...                 10.0
#
#      instant_bookable calculated_host_listings_count  \
# id
# 958                 1                              1
# 7918                0                              9
# 8142                0                              9
# 8339                0                              2
# 8739                1                              2
#
#       calculated_host_listings_count_entire_homes  \
# id
# 958                                             1
# 7918                                            0
# 8142                                            0
# 8339                                            2
# 8739                                            0
#
#       calculated_host_listings_count_private_rooms  \
# id
# 958                                              0
# 7918                                             9
# 8142                                             9
# 8339                                             0
# 8739                                             2
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month  \
# id
# 958                                             0               1.60
# 7918                                            0               0.14
# 8142                                            0               0.14
# 8339                                            0               0.23
# 8739                                            0               5.61
#
#       host_days_active  time_since_first_review  time_since_last_review
# id
# 958               3958                 4+ years                      17
# 7918              3637                 4+ years                     923
# 8142              3637                 4+ years                     263
# 8339              3622                 4+ years                     295
# 8739              3778                 4+ years                      12
#
# [5 rows x 44 columns]

# %%
from config import db_password
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import datetime as dt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_blobs
from sqlalchemy import create_engine

# %%
# Connect ML to SQL
db_string = f"postgresql://postgres:{db_password}0@127.0.0.1:5432/sf_abnb"
engine = create_engine(db_string)

# %%
ab21_df.to_sql(name='listings', con=engine)

# %%
#get list of column name
list(ab21_df.columns.values)
# Out:
# ['host_since',
#  'host_response_time',
#  'host_response_rate',
#  'host_is_superhost',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_identity_verified',
#  'neighbourhood_cleansed',
#  'zipcode',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'calendar_updated',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'instant_bookable',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month',
#  'host_days_active',
#  'time_since_first_review',
#  'time_since_last_review']

# %%
# Visually inspect the relationship between price and room_type
plt.scatter(ab21_df.room_type, ab21_df.price )
plt.xlabel('room_type')
plt.ylabel('price')
plt.show()

# %%
# Separate the feature X from the target y:
y = ab21_df["price"]
X = ab21_df.drop(columns="price")

# %%
# formats the data to meet the requirements of the Scikit-learn library:
X = ab21_df.room_type.values.reshape(-1, 1)

# %%
# Examine the first five entries in X, the output is a two-dimensional NumPy array:
X[:5]
# Out:
# array([['Entire home/apt'],
#        ['Private room'],
#        ['Private room'],
#        ['Entire home/apt'],
#        ['Private room']], dtype=object)

# %%
# Examine the shape of X
X.shape
# Out:
# (10152, 1)

# %%
# Assign the target variable, or the price column, to y
y = ab21_df.price

# %%
# Create an instance of the linear regression model.
model = LinearRegression()

# %% [markdown]
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# df2 = ab21_df.copy()
# cols = ['room_type']
# df2[cols] = df2[cols].apply(LabelEncoder().fit_transform)
# df2.head()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df2 = ab21_df.copy()
cols = ['room_type']
df2[cols] = df2[cols].apply(LabelEncoder().fit_transform)
df2.head()
# Out:
#      host_since  host_response_time host_response_rate  host_is_superhost  \
# id
# 958   7/31/2008  within a few hours               100%                  1
# 7918  6/17/2009  within a few hours               100%                  0
# 8142  6/17/2009  within a few hours               100%                  0
# 8339   7/2/2009      within an hour               100%                  0
# 8739  1/27/2009      within an hour               100%                  1
#
#       host_listings_count  host_total_listings_count  host_identity_verified  \
# id
# 958                     1                          1                       1
# 7918                   10                         10                       1
# 8142                   10                         10                       1
# 8339                    2                          2                       1
# 8739                    2                          2                       0
#
#      neighbourhood_cleansed  zipcode  latitude  ...  review_scores_value  \
# id                                              ...
# 958        Western Addition    94115  37.76931  ...                  9.0
# 7918         Haight Ashbury    94117  37.76669  ...                  8.0
# 8142         Haight Ashbury    94117  37.76487  ...                  9.0
# 8339       Western Addition    94115  37.77525  ...                  9.0
# 8739                Mission    94110  37.75919  ...                 10.0
#
#      instant_bookable  calculated_host_listings_count  \
# id
# 958                 1                               1
# 7918                0                               9
# 8142                0                               9
# 8339                0                               2
# 8739                1                               2
#
#       calculated_host_listings_count_entire_homes  \
# id
# 958                                             1
# 7918                                            0
# 8142                                            0
# 8339                                            2
# 8739                                            0
#
#       calculated_host_listings_count_private_rooms  \
# id
# 958                                              0
# 7918                                             9
# 8142                                             9
# 8339                                             0
# 8739                                             2
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month  \
# id
# 958                                             0               1.60
# 7918                                            0               0.14
# 8142                                            0               0.14
# 8339                                            0               0.23
# 8739                                            0               5.61
#
#       host_days_active  time_since_first_review  time_since_last_review
# id
# 958               3958                 4+ years                      17
# 7918              3637                 4+ years                     923
# 8142              3637                 4+ years                     263
# 8339              3622                 4+ years                     295
# 8739              3778                 4+ years                      12
#
# [5 rows x 44 columns]

# %%
df_encoded = pd.get_dummies(ab21_df, columns=["room_type"])
df_encoded.head()
# Out:
#      host_since  host_response_time host_response_rate  host_is_superhost  \
# id
# 958   7/31/2008  within a few hours               100%                  1
# 7918  6/17/2009  within a few hours               100%                  0
# 8142  6/17/2009  within a few hours               100%                  0
# 8339   7/2/2009      within an hour               100%                  0
# 8739  1/27/2009      within an hour               100%                  1
#
#       host_listings_count  host_total_listings_count  host_identity_verified  \
# id
# 958                     1                          1                       1
# 7918                   10                         10                       1
# 8142                   10                         10                       1
# 8339                    2                          2                       1
# 8739                    2                          2                       0
#
#      neighbourhood_cleansed  zipcode  latitude  ...  \
# id                                              ...
# 958        Western Addition    94115  37.76931  ...
# 7918         Haight Ashbury    94117  37.76669  ...
# 8142         Haight Ashbury    94117  37.76487  ...
# 8339       Western Addition    94115  37.77525  ...
# 8739                Mission    94110  37.75919  ...
#
#       calculated_host_listings_count_private_rooms  \
# id
# 958                                              0
# 7918                                             9
# 8142                                             9
# 8339                                             0
# 8739                                             2
#
#      calculated_host_listings_count_shared_rooms  reviews_per_month  \
# id
# 958                                            0               1.60
# 7918                                           0               0.14
# 8142                                           0               0.14
# 8339                                           0               0.23
# 8739                                           0               5.61
#
#       host_days_active  time_since_first_review  time_since_last_review  \
# id
# 958               3958                 4+ years                      17
# 7918              3637                 4+ years                     923
# 8142              3637                 4+ years                     263
# 8339              3622                 4+ years                     295
# 8739              3778                 4+ years                      12
#
#       room_type_Entire home/apt  room_type_Hotel room  room_type_Private room  \
# id
# 958                           1                     0                       0
# 7918                          0                     0                       1
# 8142                          0                     0                       1
# 8339                          1                     0                       0
# 8739                          0                     0                       1
#
#      room_type_Shared room
# id
# 958                      0
# 7918                     0
# 8142                     0
# 8339                     0
# 8739                     0
#
# [5 rows x 47 columns]

# %%
df_encoded.describe()
# Out:
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# count       10152.000000         10152.000000               10152.000000
# mean            0.508668            35.740248                  35.740248
# std             0.499949           185.968714                 185.968714
# min             0.000000             0.000000                   0.000000
# 25%             0.000000             1.000000                   1.000000
# 50%             1.000000             2.000000                   2.000000
# 75%             1.000000             5.000000                   5.000000
# max             1.000000          1987.000000                1987.000000
#
#        host_identity_verified       zipcode      latitude     longitude  \
# count            10152.000000  10152.000000  10152.000000  10152.000000
# mean                 0.746060  94113.877561     37.764742    -58.821580
# std                  0.435285      8.417610      0.022090     78.387173
# min                  0.000000  94102.000000     37.704170   -122.513060
# 25%                  0.000000  94109.000000     37.749885   -122.431370
# 50%                  1.000000  94112.000000     37.764310   -122.407840
# 75%                  1.000000  94117.000000     37.781800     37.760485
# max                  1.000000  94134.000000     37.810310     37.809540
#
#        accommodates     bathrooms      bedrooms  ...  \
# count  10152.000000  10152.000000  10152.000000  ...
# mean       3.222321      1.355595      1.438337  ...
# std        1.916934      0.856190      0.887383  ...
# min        0.000000      0.000000      0.000000  ...
# 25%        2.000000      1.000000      1.000000  ...
# 50%        2.000000      1.000000      1.000000  ...
# 75%        4.000000      1.500000      2.000000  ...
# max       16.000000     14.000000     14.000000  ...
#
#        calculated_host_listings_count_entire_homes  \
# count                                 10152.000000
# mean                                      7.371060
# std                                      29.662069
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       2.000000
# max                                     241.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  10152.000000
# mean                                       2.889775
# std                                        7.871879
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        2.000000
# max                                       56.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# count                                 10152.000000       10152.000000
# mean                                      0.465426           2.002057
# std                                       3.050391           4.176495
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.280000
# 50%                                       0.000000           0.950000
# 75%                                       0.000000           2.640000
# max                                      26.000000         156.000000
#
#        host_days_active  time_since_last_review  room_type_Entire home/apt  \
# count      10152.000000            10152.000000               10152.000000
# mean        1729.393519             -193.273739                   0.613278
# std          930.160336              519.541534                   0.487023
# min         -873.000000             -884.000000                   0.000000
# 25%         1122.000000             -792.000000                   0.000000
# 50%         1808.000000                6.000000                   1.000000
# 75%         2411.000000               64.000000                   1.000000
# max         4108.000000             2932.000000                   1.000000
#
#        room_type_Hotel room  room_type_Private room  room_type_Shared room
# count          10152.000000            10152.000000           10152.000000
# mean               0.006797                0.359338               0.020587
# std                0.082165                0.479830               0.142004
# min                0.000000                0.000000               0.000000
# 25%                0.000000                0.000000               0.000000
# 50%                0.000000                0.000000               0.000000
# 75%                0.000000                1.000000               0.000000
# max                1.000000                1.000000               1.000000
#
# [8 rows x 39 columns]

# %%
df_encoded.columns
# Out:
# Index(['host_since', 'host_response_time', 'host_response_rate',
#        'host_is_superhost', 'host_listings_count', 'host_total_listings_count',
#        'host_identity_verified', 'neighbourhood_cleansed', 'zipcode',
#        'latitude', 'longitude', 'property_type', 'accommodates', 'bathrooms',
#        'bedrooms', 'beds', 'price', 'minimum_nights', 'maximum_nights',
#        'calendar_updated', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'number_of_reviews_ltm', 'first_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'host_days_active', 'time_since_first_review', 'time_since_last_review',
#        'room_type_Entire home/apt', 'room_type_Hotel room',
#        'room_type_Private room', 'room_type_Shared room'],
#       dtype='object')

# %%
# Prepare X and y variables:
X = df_encoded[['room_type_Entire home/apt', 'room_type_Hotel room', 'room_type_Private room', 'room_type_Shared room']]
Y = df_encoded['price']
X.head(10)
# Out:
#         room_type_Entire home/apt  room_type_Hotel room  \
# id
# 958                             1                     0
# 7918                            0                     0
# 8142                            0                     0
# 8339                            1                     0
# 8739                            0                     0
# 9225                            0                     0
# 10820                           1                     0
# 10824                           1                     0
# 522273                          0                     0
# 12041                           0                     0
#
#         room_type_Private room  room_type_Shared room
# id
# 958                          0                      0
# 7918                         1                      0
# 8142                         1                      0
# 8339                         0                      0
# 8739                         1                      0
# 9225                         1                      0
# 10820                        0                      0
# 10824                        0                      0
# 522273                       1                      0
# 12041                        1                      0

# %%
print(f"Labels: {y[:10]}")
print(f"Data: {X[:10]}")
# Out:
# Labels: id
# 958       170
# 7918       65
# 8142       65
# 8339      685
# 8739      139
# 9225      135
# 10820     177
# 10824     194
# 522273     70
# 12041      85
# Name: price, dtype: int64
# Data:         room_type_Entire home/apt  room_type_Hotel room  \
# id
# 958                             1                     0
# 7918                            0                     0
# 8142                            0                     0
# 8339                            1                     0
# 8739                            0                     0
# 9225                            0                     0
# 10820                           1                     0
# 10824                           1                     0
# 522273                          0                     0
# 12041                           0                     0
#
#         room_type_Private room  room_type_Shared room
# id
# 958                          0                      0
# 7918                         1                      0
# 8142                         1                      0
# 8339                         0                      0
# 8739                         1                      0
# 9225                         1                      0
# 10820                        0                      0
# 10824                        0                      0
# 522273                       1                      0
# 12041                        1                      0

# %%
from sklearn.model_selection import train_test_split
# pass X, y into the train_test_split() function
x_train, x_test,y_train,y_test = train_test_split(X,Y,test_size =0.2, random_state=1)
# print the data
x_train
# Out:
#           room_type_Entire home/apt  room_type_Hotel room  \
# id
# 39005339                          1                     0
# 31490601                          1                     0
# 1018426                           0                     0
# 2172308                           1                     0
# 16179580                          1                     0
# ...                             ...                   ...
# 17543814                          0                     0
# 24736036                          0                     0
# 2944843                           0                     0
# 285499                            1                     0
# 456568                            0                     0
#
#           room_type_Private room  room_type_Shared room
# id
# 39005339                       0                      0
# 31490601                       0                      0
# 1018426                        0                      1
# 2172308                        0                      0
# 16179580                       0                      0
# ...                          ...                    ...
# 17543814                       0                      1
# 24736036                       1                      0
# 2944843                        1                      0
# 285499                         0                      0
# 456568                         1                      0
#
# [8121 rows x 4 columns]

# %%
#create an object of the LinearRegression class.
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
#fit the x_train and y_train variables.
clf.fit(x_train,y_train.values.ravel())
# Out:
# LinearRegression()

# %%
#predict the output by passing the x_test variable.
clf.predict(x_test)
# Out:
# array([143.75, 143.75, 257.  , ..., 257.  , 110.5 , 257.  ])

# %%
#Accuracy
clf.score(x_test,y_test)
# Out:
# 0.03502930670645843

# %%
#After a model is instantiated, it will analyze the data and attempt to learn patterns in the data. 
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Generate prediction
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (10152,)

# %% [markdown]
# # ML for the 2nd segment: Linear Regression price vs review_scores_rating

# %%
# Load the listings_cleaned2.csv which has the zipcode updated Jan16
file_path = "./resources/listings_cleaned2_Modified.csv"
df_w_zipcode = pd.read_csv(file_path,index_col=0)
df_w_zipcode.head()
# Out:
#      host_since  host_response_time host_response_rate  host_is_superhost  \
# id
# 958   7/31/2008  within a few hours               100%                  1
# 7918  6/17/2009  within a few hours               100%                  0
# 8142  6/17/2009  within a few hours               100%                  0
# 8339   7/2/2009      within an hour               100%                  0
# 8739  1/27/2009      within an hour               100%                  1
#
#       host_listings_count  host_total_listings_count  host_identity_verified  \
# id
# 958                     1                          1                       1
# 7918                   10                         10                       1
# 8142                   10                         10                       1
# 8339                    2                          2                       1
# 8739                    2                          2                       0
#
#      neighbourhood_cleansed  zipcode  latitude  ...  review_scores_value  \
# id                                              ...
# 958        Western Addition    94115  37.76931  ...                  9.0
# 7918         Haight Ashbury    94117  37.76669  ...                  8.0
# 8142         Haight Ashbury    94117  37.76487  ...                  9.0
# 8339       Western Addition    94115  37.77525  ...                  9.0
# 8739                Mission    94110  37.75919  ...                 10.0
#
#      instant_bookable calculated_host_listings_count  \
# id
# 958                 1                              1
# 7918                0                              9
# 8142                0                              9
# 8339                0                              2
# 8739                1                              2
#
#       calculated_host_listings_count_entire_homes  \
# id
# 958                                             1
# 7918                                            0
# 8142                                            0
# 8339                                            2
# 8739                                            0
#
#       calculated_host_listings_count_private_rooms  \
# id
# 958                                              0
# 7918                                             9
# 8142                                             9
# 8339                                             0
# 8739                                             2
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month  \
# id
# 958                                             0               1.60
# 7918                                            0               0.14
# 8142                                            0               0.14
# 8339                                            0               0.23
# 8739                                            0               5.61
#
#       host_days_active  time_since_first_review  time_since_last_review
# id
# 958               3958                 4+ years                      17
# 7918              3637                 4+ years                     923
# 8142              3637                 4+ years                     263
# 8339              3622                 4+ years                     295
# 8739              3778                 4+ years                      12
#
# [5 rows x 44 columns]

# %%
from config import db_password
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import datetime as dt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_blobs
from sqlalchemy import create_engine

# %%
# Connect ML to SQL
db_string = f"postgresql://postgres:{db_password}0@127.0.0.1:5432/sf_abnb"
engine = create_engine(db_string)

# %%
df_w_zipcode.to_sql(name='listings', con=engine)

# %%
#get list of column name
list(df_w_zipcode.columns.values)
# Out:
# ['host_since',
#  'host_response_time',
#  'host_response_rate',
#  'host_is_superhost',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_identity_verified',
#  'neighbourhood_cleansed',
#  'zipcode',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'calendar_updated',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'instant_bookable',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month',
#  'host_days_active',
#  'time_since_first_review',
#  'time_since_last_review']

# %%
# Visually inspect the relationship between price and review_scores_rating
plt.scatter(df_w_zipcode.review_scores_rating, df_w_zipcode.price )
plt.xlabel('review_scores_rating')
plt.ylabel('price')
plt.show()

# %%
# formats the data to meet the requirements of the Scikit-learn library:
X = df_w_zipcode.review_scores_rating.values.reshape(-1, 1)

# %%
# Examine the first five entries in X, the output is a two-dimensional NumPy array:
X[:5]
# Out:
# array([[97.],
#        [85.],
#        [93.],
#        [97.],
#        [98.]])

# %%
# Examine the shape of X, there are 10152 rows and 1 column:
X.shape
# Out:
# (10152, 1)

# %%
# Assign the target variable, or the Price column, to y
y = df_w_zipcode.price

# %%
model = LinearRegression()

# %%
# After a model is instantiated, it will analyze the data and attempt to learn patterns in the data. 
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Generate predictions: given any number review_scores_rating, the model will predict the price:
#Based on the 10152 available data points in X, model.predict(X) returned 10152 predictions
#through which a straight line can be drawn.
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (10152,)

# %%
# plot the predictions as a red line against the data points:
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
plt.savefig('linear.price.review.png')

# %% [markdown]
# # # ML for the 2nd segment: Logistic Regression price vs bedrooms

# %%
df_w_zipcode.dtypes
# Out:
# host_since                                       object
# host_response_time                               object
# host_response_rate                               object
# host_is_superhost                                 int64
# host_listings_count                               int64
# host_total_listings_count                         int64
# host_identity_verified                            int64
# neighbourhood_cleansed                           object
# zipcode                                           int64
# latitude                                        float64
# longitude                                       float64
# property_type                                    object
# room_type                                        object
# accommodates                                      int64
# bathrooms                                       float64
# bedrooms                                          int64
# beds                                              int64
# price                                             int64
# minimum_nights                                    int64
# maximum_nights                                    int64
# calendar_updated                                 object
# availability_30                                   int64
# availability_60                                   int64
# availability_90                                   int64
# availability_365                                  int64
# number_of_reviews                                 int64
# number_of_reviews_ltm                             int64
# first_review                                     object
# review_scores_rating                            float64
# review_scores_accuracy                          float64
# review_scores_cleanliness                       float64
# review_scores_checkin                           float64
# review_scores_communication                     float64
# review_scores_location                          float64
# review_scores_value                             float64
# instant_bookable                                  int64
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# host_days_active                                  int64
# time_since_first_review                          object
# time_since_last_review                            int64
# dtype: object

# %%
# Create two clusters of data named X and y:
# Separate the feature X from the target y:
X = df_w_zipcode.drop(columns=['price', 'host_since', 'host_response_time', 'host_response_rate', 'neighbourhood_cleansed', 'property_type', 'room_type', 'calendar_updated', 'time_since_first_review', 'first_review' ])
X = pd.get_dummies(X, columns=["bedrooms"])

# Create our target
y = df_w_zipcode['price'].to_frame()

# %%
X.describe()
# Out:
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# count       10152.000000         10152.000000               10152.000000
# mean            0.508668            35.740248                  35.740248
# std             0.499949           185.968714                 185.968714
# min             0.000000             0.000000                   0.000000
# 25%             0.000000             1.000000                   1.000000
# 50%             1.000000             2.000000                   2.000000
# 75%             1.000000             5.000000                   5.000000
# max             1.000000          1987.000000                1987.000000
#
#        host_identity_verified       zipcode      latitude     longitude  \
# count            10152.000000  10152.000000  10152.000000  10152.000000
# mean                 0.746060  94113.877561     37.764742    -58.821580
# std                  0.435285      8.417610      0.022090     78.387173
# min                  0.000000  94102.000000     37.704170   -122.513060
# 25%                  0.000000  94109.000000     37.749885   -122.431370
# 50%                  1.000000  94112.000000     37.764310   -122.407840
# 75%                  1.000000  94117.000000     37.781800     37.760485
# max                  1.000000  94134.000000     37.810310     37.809540
#
#        accommodates     bathrooms          beds  ...    bedrooms_2  \
# count  10152.000000  10152.000000  10152.000000  ...  10152.000000
# mean       3.222321      1.355595      1.809200  ...      0.200650
# std        1.916934      0.856190      1.208914  ...      0.400506
# min        0.000000      0.000000      0.000000  ...      0.000000
# 25%        2.000000      1.000000      1.000000  ...      0.000000
# 50%        2.000000      1.000000      1.000000  ...      0.000000
# 75%        4.000000      1.500000      2.000000  ...      0.000000
# max       16.000000     14.000000     14.000000  ...      1.000000
#
#          bedrooms_3    bedrooms_4    bedrooms_5    bedrooms_6    bedrooms_7  \
# count  10152.000000  10152.000000  10152.000000  10152.000000  10152.000000
# mean       0.089835      0.024724      0.004137      0.001478      0.000296
# std        0.285959      0.155291      0.064190      0.038412      0.017189
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#          bedrooms_8    bedrooms_9   bedrooms_11   bedrooms_14
# count  10152.000000  10152.000000  10152.000000  10152.000000
# mean       0.000099      0.000099      0.000099      0.000099
# std        0.009925      0.009925      0.009925      0.009925
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000
#
# [8 rows x 45 columns]

# %%
# Check the balance of our target values
y['price'].value_counts()
# Out:
# 150     310
# 100     244
# 250     238
# 125     208
# 200     182
#        ...
# 930       1
# 5000      1
# 890       1
# 714       1
# 1999      1
# Name: price, Length: 600, dtype: int64

# %%
# The dataset is split into training and testing sets.
from sklearn.model_selection import train_test_split
from collections import Counter
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_train.shape
# Out:
# (7614, 45)

# %%
Counter(y_train)
# Out:
# Counter({'price': 1})

# %%
plt.scatter(df_w_zipcode.bedrooms, df_w_zipcode.price)
plt.xlabel('bedrooms')
plt.ylabel('price')
plt.savefig('ml.logistic.price.bedroom.png')
#plt.show()

# %%
# Resample the training data with the RandomOversampler
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=1)
X_resampled, y_resampled = ros.fit_resample(X_train, y_train.values.ravel())

# %%
# Counting the classes of the resampled target verifies that the minority class has been enlarged.
Counter(y_resampled)
# Out:
# Counter({175: 233,
#          260: 233,
#          110: 233,
#          45: 233,
#          999: 233,
#          250: 233,
#          229: 233,
#          90: 233,
#          185: 233,
#          322: 233,
#          124: 233,
#          210: 233,
#          100: 233,
#          200: 233,
#          58: 233,
#          86: 233,
#          38: 233,
#          153: 233,
#          89: 233,
#          199: 233,
#          170: 233,
#          280: 233,
#          145: 233,
#          180: 233,
#          138: 233,
#          30: 233,
#          112: 233,
#          800: 233,
#          120: 233,
#          350: 233,
#          130: 233,
#          119: 233,
#          88: 233,
#          52: 233,
#          95: 233,
#          248: 233,
#          99: 233,
#          129: 233,
#          150: 233,
#          106: 233,
#          555: 233,
#          105: 233,
#          75: 233,
#          380: 233,
#          108: 233,
#          125: 233,
#          83: 233,
#          80: 233,
#          270: 233,
#          165: 233,
#          685: 233,
#          1000: 233,
#          335: 233,
#          77: 233,
#          190: 233,
#          107: 233,
#          151: 233,
#          282: 233,
#          94: 233,
#          73: 233,
#          160: 233,
#          425: 233,
#          790: 233,
#          159: 233,
#          169: 233,
#          85: 233,
#          78: 233,
#          123: 233,
#          60: 233,
#          147: 233,
#          195: 233,
#          429: 233,
#          373: 233,
#          164: 233,
#          111: 233,
#          299: 233,
#          295: 233,
#          245: 233,
#          98: 233,
#          267: 233,
#          230: 233,
#          131: 233,
#          182: 233,
#          189: 233,
#          209: 233,
#          400: 233,
#          59: 233,
#          243: 233,
#          450: 233,
#          595: 233,
#          135: 233,
#          202: 233,
#          340: 233,
#          187: 233,
#          81: 233,
#          140: 233,
#          234: 233,
#          225: 233,
#          249: 233,
#          33: 233,
#          56: 233,
#          235: 233,
#          68: 233,
#          172: 233,
#          50: 233,
#          300: 233,
#          47: 233,
#          390: 233,
#          136: 233,
#          115: 233,
#          500: 233,
#          137: 233,
#          96: 233,
#          70: 233,
#          1495: 233,
#          139: 233,
#          290: 233,
#          529: 233,
#          218: 233,
#          109: 233,
#          87: 233,
#          155: 233,
#          132: 233,
#          156: 233,
#          287: 233,
#          61: 233,
#          265: 233,
#          101: 233,
#          167: 233,
#          275: 233,
#          146: 233,
#          220: 233,
#          449: 233,
#          326: 233,
#          600: 233,
#          97: 233,
#          55: 233,
#          28: 233,
#          495: 233,
#          2000: 233,
#          355: 233,
#          143: 233,
#          221: 233,
#          241: 233,
#          142: 233,
#          57: 233,
#          69: 233,
#          269: 233,
#          1200: 233,
#          174: 233,
#          152: 233,
#          325: 233,
#          79: 233,
#          750: 233,
#          445: 233,
#          650: 233,
#          197: 233,
#          288: 233,
#          134: 233,
#          93: 233,
#          44: 233,
#          104: 233,
#          196: 233,
#          65: 233,
