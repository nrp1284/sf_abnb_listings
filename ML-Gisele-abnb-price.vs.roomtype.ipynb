# %%
# %matplotlib inline

# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import hvplot.pandas
from pathlib import Path
import plotly.express as px
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_blobs

# %%
# Load the dataset.
file_path = "./resources/listings_cleaned2.csv"
ab21_df = pd.read_csv(file_path,index_col=0)
ab21_df.head(5)
# Out:
#      host_since  host_response_time host_response_rate  host_is_superhost  \
# id
# 958   7/31/2008  within a few hours               100%                  1
# 7918  6/17/2009  within a few hours               100%                  0
# 8142  6/17/2009  within a few hours               100%                  0
# 8339   7/2/2009      within an hour               100%                  0
# 8739  1/27/2009      within an hour               100%                  1
#
#       host_listings_count  host_total_listings_count  host_identity_verified  \
# id
# 958                     1                          1                       1
# 7918                   10                         10                       1
# 8142                   10                         10                       1
# 8339                    2                          2                       1
# 8739                    2                          2                       0
#
#      neighbourhood_cleansed property_type        room_type  ...  \
# id                                                          ...
# 958        Western Addition     Apartment  Entire home/apt  ...
# 7918         Haight Ashbury     Apartment     Private room  ...
# 8142         Haight Ashbury     Apartment     Private room  ...
# 8339       Western Addition         House  Entire home/apt  ...
# 8739                Mission         Other     Private room  ...
#
#       review_scores_value instant_bookable  calculated_host_listings_count  \
# id
# 958                   9.0                1                               1
# 7918                  8.0                0                               9
# 8142                  9.0                0                               9
# 8339                  9.0                0                               2
# 8739                 10.0                1                               2
#
#       calculated_host_listings_count_entire_homes  \
# id
# 958                                             1
# 7918                                            0
# 8142                                            0
# 8339                                            2
# 8739                                            0
#
#       calculated_host_listings_count_private_rooms  \
# id
# 958                                              0
# 7918                                             9
# 8142                                             9
# 8339                                             0
# 8739                                             2
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month  \
# id
# 958                                             0               1.60
# 7918                                            0               0.14
# 8142                                            0               0.14
# 8339                                            0               0.23
# 8739                                            0               5.61
#
#      host_days_active  time_since_first_review  time_since_last_review
# id
# 958              3958                 4+ years                      17
# 7918             3637                 4+ years                     923
# 8142             3637                 4+ years                     263
# 8339             3622                 4+ years                     295
# 8739             3778                 4+ years                      12
#
# [5 rows x 41 columns]

# %%
from config import db_password
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import datetime as dt
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_blobs
from sqlalchemy import create_engine

# %%
# Connect ML to SQL
db_string = f"postgresql://postgres:{db_password}0@127.0.0.1:5432/sf_abnb"
engine = create_engine(db_string)

# %%
ab21_df.to_sql(name='listings', con=engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#
# C:\ProgramData\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-33-7cbd4535ffaf> in <module>
# ----> 1 ab21_df.to_sql(name='listings', con=engine)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404             dtype=dtype,
#    1405         )
# -> 1406         table.create()
#    1407
#    1408         from sqlalchemy import exc
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     734
#     735     def create(self):
# --> 736         if self.exists():
#     737             if self.if_exists == "fail":
#     738                 raise ValueError(f"Table '{self.name}' already exists.")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in exists(self)
#     718
#     719     def exists(self):
# --> 720         return self.pd_sql.has_table(self.name, self.schema)
#     721
#     722     def sql_schema(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1452             import sqlalchemy as sa
#    1453
# -> 1454             insp = sa.inspect(self.connectable)
#    1455             return insp.has_table(name, schema or self.meta.schema)
#    1456         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\inspection.py in inspect(subject, raiseerr)
#      62             if reg is True:
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#      66                 break
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _engine_insp(bind)
#     180     @inspection._inspects(Engine)
#     181     def _engine_insp(bind):
# --> 182         return Inspector._construct(Inspector._init_engine, bind)
#     183
#     184     @inspection._inspects(Connection)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _construct(cls, init, bind)
#     115
#     116         self = cls.__new__(cls)
# --> 117         init(self, bind)
#     118         return self
#     119
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\reflection.py in _init_engine(self, engine)
#     126     def _init_engine(self, engine):
#     127         self.bind = self.engine = engine
# --> 128         engine.connect().close()
#     129         self._op_context_requires_connect = True
#     130         self.dialect = self.engine.dialect
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3093         """
#    3094
# -> 3095         return self._connection_cls(self, close_with_result=close_with_result)
#    3096
#    3097     @util.deprecated(
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      89                 connection
#      90                 if connection is not None
# ---> 91                 else engine.raw_connection()
#      92             )
#      93
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3172
#    3173         """
# -> 3174         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3175
#    3176
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
# -> 3144                 Connection._handle_dbapi_exception_noconnection(
#    3145                     e, dialect, self
#    3146                 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2001             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2002         elif should_wrap:
# -> 2003             util.raise_(
#    2004                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2005             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3139         dialect = self.dialect
#    3140         try:
# -> 3141             return fn()
#    3142         except dialect.dbapi.Error as e:
#    3143             if connection is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     299
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#     303     def _return_conn(self, record):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     753     def _checkout(cls, pool, threadconns=None, fairy=None):
#     754         if not fairy:
# --> 755             fairy = _ConnectionRecord.checkout(pool)
#     756
#     757             fairy._pool = pool
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     417     @classmethod
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#     421             dbapi_connection = rec.get_connection()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     143             except:
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#     147             return self._do_get()
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     140         if self._inc_overflow():
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#     144                 with util.safe_reraise():
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     245         """Called by subclasses to create a new ConnectionRecord."""
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#     249     def _invalidate(self, connection, exception=None, _checkin=True):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     360         self.__pool = pool
#     361         if connect:
# --> 362             self.__connect(first_connect_check=True)
#     363         self.finalize_callback = deque()
#     364
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     603         except Exception as e:
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#     607             if first_connect_check:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     597         try:
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#     601             self.connection = connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     557     def connect(self, *cargs, **cparams):
#     558         # inherits the docstring from interfaces.Dialect.connect
# --> 559         return self.dbapi.connect(*cargs, **cparams)
#     560
#     561     def create_connect_args(self, url):
#
# C:\ProgramData\Anaconda3\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
#get list of column name
list(ab21_df.columns.values)
# Out:
# ['host_since',
#  'host_response_time',
#  'host_response_rate',
#  'host_is_superhost',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_identity_verified',
#  'neighbourhood_cleansed',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'calendar_updated',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'instant_bookable',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month',
#  'host_days_active',
#  'time_since_first_review',
#  'time_since_last_review']

# %%
# Visually inspect the relationship between price and room_type
plt.scatter(ab21_df.room_type, ab21_df.price )
plt.xlabel('room_type')
plt.ylabel('price')
plt.show()

# %%
# Separate the feature X from the target y:
y = ab21_df["price"]
X = ab21_df.drop(columns="price")

# %%
# formats the data to meet the requirements of the Scikit-learn library:
X = ab21_df.room_type.values.reshape(-1, 1)

# %%
# Examine the first five entries in X, the output is a two-dimensional NumPy array:
X[:5]
# Out:
# array([['Entire home/apt'],
#        ['Private room'],
#        ['Private room'],
#        ['Entire home/apt'],
#        ['Private room']], dtype=object)

# %%
# Examine the shape of X
X.shape
# Out:
# (10153, 1)

# %%
# Assign the target variable, or the price column, to y
y = ab21_df.price

# %%
# Create an instance of the linear regression model.
model = LinearRegression()

# %% [markdown]
# from sklearn.preprocessing import LabelEncoder
# le = LabelEncoder()
# df2 = ab21_df.copy()
# cols = ['room_type']
# df2[cols] = df2[cols].apply(LabelEncoder().fit_transform)
# df2.head()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df2 = ab21_df.copy()
cols = ['room_type']
df2[cols] = df2[cols].apply(LabelEncoder().fit_transform)
df2.head()
# Out:
#      host_since  host_response_time host_response_rate  host_is_superhost  \
# id
# 958   7/31/2008  within a few hours               100%                  1
# 7918  6/17/2009  within a few hours               100%                  0
# 8142  6/17/2009  within a few hours               100%                  0
# 8339   7/2/2009      within an hour               100%                  0
# 8739  1/27/2009      within an hour               100%                  1
#
#       host_listings_count  host_total_listings_count  host_identity_verified  \
# id
# 958                     1                          1                       1
# 7918                   10                         10                       1
# 8142                   10                         10                       1
# 8339                    2                          2                       1
# 8739                    2                          2                       0
#
#      neighbourhood_cleansed property_type  room_type  ...  \
# id                                                    ...
# 958        Western Addition     Apartment          0  ...
# 7918         Haight Ashbury     Apartment          2  ...
# 8142         Haight Ashbury     Apartment          2  ...
# 8339       Western Addition         House          0  ...
# 8739                Mission         Other          2  ...
#
#       review_scores_value instant_bookable  calculated_host_listings_count  \
# id
# 958                   9.0                1                               1
# 7918                  8.0                0                               9
# 8142                  9.0                0                               9
# 8339                  9.0                0                               2
# 8739                 10.0                1                               2
#
#       calculated_host_listings_count_entire_homes  \
# id
# 958                                             1
# 7918                                            0
# 8142                                            0
# 8339                                            2
# 8739                                            0
#
#       calculated_host_listings_count_private_rooms  \
# id
# 958                                              0
# 7918                                             9
# 8142                                             9
# 8339                                             0
# 8739                                             2
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month  \
# id
# 958                                             0               1.60
# 7918                                            0               0.14
# 8142                                            0               0.14
# 8339                                            0               0.23
# 8739                                            0               5.61
#
#      host_days_active  time_since_first_review  time_since_last_review
# id
# 958              3958                 4+ years                      17
# 7918             3637                 4+ years                     923
# 8142             3637                 4+ years                     263
# 8339             3622                 4+ years                     295
# 8739             3778                 4+ years                      12
#
# [5 rows x 41 columns]

# %%
df_encoded = pd.get_dummies(ab21_df, columns=["room_type"])
df_encoded.head()
# Out:
#      host_since  host_response_time host_response_rate  host_is_superhost  \
# id
# 958   7/31/2008  within a few hours               100%                  1
# 7918  6/17/2009  within a few hours               100%                  0
# 8142  6/17/2009  within a few hours               100%                  0
# 8339   7/2/2009      within an hour               100%                  0
# 8739  1/27/2009      within an hour               100%                  1
#
#       host_listings_count  host_total_listings_count  host_identity_verified  \
# id
# 958                     1                          1                       1
# 7918                   10                         10                       1
# 8142                   10                         10                       1
# 8339                    2                          2                       1
# 8739                    2                          2                       0
#
#      neighbourhood_cleansed property_type  accommodates  ...  \
# id                                                       ...
# 958        Western Addition     Apartment             3  ...
# 7918         Haight Ashbury     Apartment             2  ...
# 8142         Haight Ashbury     Apartment             2  ...
# 8339       Western Addition         House             5  ...
# 8739                Mission         Other             3  ...
#
#      calculated_host_listings_count_private_rooms  \
# id
# 958                                             0
# 7918                                            9
# 8142                                            9
# 8339                                            0
# 8739                                            2
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month  \
# id
# 958                                             0               1.60
# 7918                                            0               0.14
# 8142                                            0               0.14
# 8339                                            0               0.23
# 8739                                            0               5.61
#
#       host_days_active  time_since_first_review  time_since_last_review  \
# id
# 958               3958                 4+ years                      17
# 7918              3637                 4+ years                     923
# 8142              3637                 4+ years                     263
# 8339              3622                 4+ years                     295
# 8739              3778                 4+ years                      12
#
#      room_type_Entire home/apt  room_type_Hotel room  room_type_Private room  \
# id
# 958                          1                     0                       0
# 7918                         0                     0                       1
# 8142                         0                     0                       1
# 8339                         1                     0                       0
# 8739                         0                     0                       1
#
#       room_type_Shared room
# id
# 958                       0
# 7918                      0
# 8142                      0
# 8339                      0
# 8739                      0
#
# [5 rows x 44 columns]

# %%
df_encoded.describe()
# Out:
#        host_is_superhost  host_listings_count  host_total_listings_count  \
# count       10153.000000         10153.000000               10153.000000
# mean            0.508618            35.736827                  35.736827
# std             0.499950           185.959874                 185.959874
# min             0.000000             0.000000                   0.000000
# 25%             0.000000             1.000000                   1.000000
# 50%             1.000000             2.000000                   2.000000
# 75%             1.000000             5.000000                   5.000000
# max             1.000000          1987.000000                1987.000000
#
#        host_identity_verified  accommodates     bedrooms         beds  \
# count            10153.000000  10153.000000  9425.000000  9972.000000
# mean                 0.746085      3.222299     1.449655     1.821400
# std                  0.435271      1.916841     0.903819     1.214483
# min                  0.000000      0.000000     0.000000     0.000000
# 25%                  0.000000      2.000000     1.000000     1.000000
# 50%                  1.000000      2.000000     1.000000     1.000000
# 75%                  1.000000      4.000000     2.000000     2.000000
# max                  1.000000     16.000000    14.000000    14.000000
#
#               price  minimum_nights  maximum_nights  ...  \
# count  10153.000000    1.015300e+04    1.015300e+04  ...
# mean     214.417512    9.864565e+03    1.031912e+04  ...
# std      363.594047    9.924365e+05    9.924327e+05  ...
# min        0.000000    1.000000e+00    1.000000e+00  ...
# 25%       99.000000    2.000000e+00    2.800000e+01  ...
# 50%      150.000000    3.000000e+00    1.200000e+02  ...
# 75%      240.000000    3.000000e+01    1.125000e+03  ...
# max    25000.000000    1.000000e+08    1.000000e+08  ...
#
#        calculated_host_listings_count_entire_homes  \
# count                                 10153.000000
# mean                                      7.370334
# std                                      29.660699
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                       2.000000
# max                                     241.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                  10153.000000
# mean                                       2.889589
# std                                        7.871513
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        2.000000
# max                                       56.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month  \
# count                                 10153.000000       10153.000000
# mean                                      0.465380           2.001884
# std                                       3.050244           4.176326
# min                                       0.000000           0.010000
# 25%                                       0.000000           0.280000
# 50%                                       0.000000           0.950000
# 75%                                       0.000000           2.640000
# max                                      26.000000         156.000000
#
#        host_days_active  time_since_last_review  room_type_Entire home/apt  \
# count      10153.000000            10153.000000               10153.000000
# mean        1729.616567             -193.198267                   0.613218
# std          930.386018              519.571603                   0.487037
# min         -873.000000             -884.000000                   0.000000
# 25%         1122.000000             -792.000000                   0.000000
# 50%         1808.000000                6.000000                   1.000000
# 75%         2411.000000               64.000000                   1.000000
# max         4108.000000             2932.000000                   1.000000
#
#        room_type_Hotel room  room_type_Private room  room_type_Shared room
# count          10153.000000            10153.000000           10153.000000
# mean               0.006796                0.359401               0.020585
# std                0.082161                0.479849               0.141998
# min                0.000000                0.000000               0.000000
# 25%                0.000000                0.000000               0.000000
# 50%                0.000000                0.000000               0.000000
# 75%                0.000000                1.000000               0.000000
# max                1.000000                1.000000               1.000000
#
# [8 rows x 35 columns]

# %%
# Prepare X and y variables:
X = df2[['room_type']]
Y = df2['price']
X.head(10)
# Out:
#        room_type
# id
# 958            0
# 7918           2
# 8142           2
# 8339           0
# 8739           2
# 9225           2
# 10820          0
# 10824          0
# 10832          0
# 12041          2

# %%
print(f"Labels: {y[:10]}")
print(f"Data: {X[:10]}")
# Out:
# Labels: id
# 958      170
# 7918      65
# 8142      65
# 8339     685
# 8739     139
# 9225     135
# 10820    177
# 10824    194
# 10832    139
# 12041     85
# Name: price, dtype: int64
# Data:        room_type
# id
# 958            0
# 7918           2
# 8142           2
# 8339           0
# 8739           2
# 9225           2
# 10820          0
# 10824          0
# 10832          0
# 12041          2

# %%
# pass X, y into the train_test_split() function
x_train, x_test,y_train,y_test = train_test_split(X,Y,test_size =0.2, random_state=1)
# print the data
x_train
# Out:
#           room_type
# id
# 39005339          0
# 31474637          0
# 1018426           3
# 2169208           0
# 16179065          0
# ...             ...
# 17543317          2
# 24722081          0
# 2944843           2
# 284117            0
# 456568            2
#
# [8122 rows x 1 columns]

# %%
#create an object of the LinearRegression class.
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
#fit the x_train and y_train variables.
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#predict the output by passing the x_test variable.
clf.predict(x_test)
# Out:
# array([149.56432709, 149.56432709, 149.56432709, ..., 255.59706936,
#        149.56432709, 149.56432709])

# %%
#Accuracy
clf.score(x_test,y_test)
# Out:
# 0.028653171618621687

# %%
#After a model is instantiated, it will analyze the data and attempt to learn patterns in the data. 
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#Generate prediction
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (10153,)

# %%
# plot the predictions as a red line against the data points:
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()
