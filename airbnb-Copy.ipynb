# %%
# %matplotlib inline

# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import hvplot.pandas
from pathlib import Path

# %%
# Load the crypto_data.csv modified dataset includng current 2021 data

file_path = "./resources/sf_airbnb_listings_modified.csv"
ab_df = pd.read_csv(file_path,index_col=0)
ab_df.head()
# Out:
# C:\anaconda\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (30,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                             listing_url     scrape_id last_scraped  \
# id
# 958    https://www.airbnb.com/rooms/958  2.020000e+13     6/2/2019
# 7918  https://www.airbnb.com/rooms/7918  2.020000e+13     6/2/2019
# 8142  https://www.airbnb.com/rooms/8142  2.020000e+13     6/2/2019
# 8339  https://www.airbnb.com/rooms/8339  2.020000e+13     6/2/2019
# 8739  https://www.airbnb.com/rooms/8739  2.020000e+13     6/2/2019
#
#                                                    name  \
# id
# 958                 Bright, Modern Garden Unit - 1BR/1B
# 7918         A Friendly Room - UCSF/USF - San Francisco
# 8142  Friendly Room Apt. Style -UCSF/USF - San Franc...
# 8339                    Historic Alamo Square Victorian
# 8739                Mission Sunshine, with Private Bath
#
#                                             description  \
# id
# 958   New update: the house next door is under const...
# 7918  Nice and good public transportation.  7 minute...
# 8142  Nice and good public transportation.  7 minute...
# 8339  Pls email before booking.  Interior featured i...
# 8739  Welcome to The Mission, the sunniest neighborh...
#
#                                   neighborhood_overview  \
# id
# 958   *Quiet cul de sac in friendly neighborhood *St...
# 7918  Shopping old town, restaurants, McDonald, Whol...
# 8142                                                NaN
# 8339                                                NaN
# 8739  Located between Valencia Street and Dolores Pa...
#
#                                             picture_url  host_id  \
# id
# 958   https://a0.muscache.com/im/pictures/b7c2a199-4...     1169
# 7918  https://a0.muscache.com/im/pictures/26356/8030...    21994
# 8142  https://a0.muscache.com/im/pictures/27832/3b1f...    21994
# 8339  https://a0.muscache.com/im/pictures/213fbf05-3...    24215
# 8739  https://a0.muscache.com/im/pictures/80811/7a57...     7149
#
#                                      host_url     host_name host_since  \
# id
# 958    https://www.airbnb.com/users/show/1169         Holly  7/31/2008
# 7918  https://www.airbnb.com/users/show/21994         Aaron  6/17/2009
# 8142  https://www.airbnb.com/users/show/21994         Aaron  6/17/2009
# 8339  https://www.airbnb.com/users/show/24215          Rosy   7/2/2009
# 8739   https://www.airbnb.com/users/show/7149  Ivan & Wendy  1/27/2009
#
#                                  host_location  \
# id
# 958   San Francisco, California, United States
# 7918  San Francisco, California, United States
# 8142  San Francisco, California, United States
# 8339  San Francisco, California, United States
# 8739  San Francisco, California, United States
#
#                                              host_about  host_response_time  \
# id
# 958   We are a family with 2 boys born in 2009 and 2...  within a few hours
# 7918  7 minutes walk to UCSF.  15 minutes walk to US...  within a few hours
# 8142  7 minutes walk to UCSF.  15 minutes walk to US...  within a few hours
# 8339  I''''m in Interior Stylist living in SF. \r\n\...      within an hour
# 8739  Ivan is a publisher of a book for 4 year olds....      within an hour
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# id
# 958                100%                  NaN                 t
# 7918               100%                  NaN                 f
# 8142               100%                  NaN                 f
# 8339               100%                  NaN                 f
# 8739               100%                  NaN                 t
#
#                                      host_thumbnail_url  \
# id
# 958   https://a0.muscache.com/im/pictures/efdad96a-3...
# 7918  https://a0.muscache.com/im/users/21994/profile...
# 8142  https://a0.muscache.com/im/users/21994/profile...
# 8339  https://a0.muscache.com/im/pictures/user/a7919...
# 8739  https://a0.muscache.com/im/users/7149/profile_...
#
#                                        host_picture_url host_neighbourhood  \
# id
# 958   https://a0.muscache.com/im/pictures/efdad96a-3...    Duboce Triangle
# 7918  https://a0.muscache.com/im/users/21994/profile...        Cole Valley
# 8142  https://a0.muscache.com/im/users/21994/profile...        Cole Valley
# 8339  https://a0.muscache.com/im/pictures/user/a7919...       Alamo Square
# 8739  https://a0.muscache.com/im/users/7149/profile_...   Mission District
#
#       host_listings_count  host_total_listings_count  \
# id
# 958                     1                          1
# 7918                   10                         10
# 8142                   10                         10
# 8339                    2                          2
# 8739                    2                          2
#
#                                      host_verifications host_has_profile_pic  \
# id
# 958   [''''email'''', ''''phone'''', ''''facebook'''...                    t
# 7918  [''''email'''', ''''phone'''', ''''reviews''''...                    t
# 8142  [''''email'''', ''''phone'''', ''''reviews''''...                    t
# 8339  [''''email'''', ''''phone'''', ''''reviews''''...                    t
# 8739  [''''email'''', ''''phone'''', ''''reviews''''...                    t
#
#      host_identity_verified     neighbourhood neighbourhood_cleansed  ...  \
# id                                                                    ...
# 958                       t      Lower Haight       Western Addition  ...
# 7918                      t       Cole Valley         Haight Ashbury  ...
# 8142                      t       Cole Valley         Haight Ashbury  ...
# 8339                      t      Alamo Square       Western Addition  ...
# 8739                      f  Mission District                Mission  ...
#
#       minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# id
# 958                      1.0                    30.0     2 months ago
# 7918                    32.0                    60.0    19 months ago
# 8142                    32.0                    90.0    19 months ago
# 8339                     4.0                  1125.0      2 weeks ago
# 8739                     1.0                    14.0      2 weeks ago
#
#      has_availability availability_30  availability_60 availability_90  \
# id
# 958                 t               1                3               7
# 7918                t              30               60              90
# 8142                t              11               41              71
# 8339                t              30               60              90
# 8739                t              11               38              64
#
#       availability_365  calendar_last_scraped number_of_reviews  \
# id
# 958                 92               6/2/2019               192
# 7918               365               6/2/2019                17
# 8142               346               6/2/2019                 8
# 8339                90               6/2/2019                27
# 8739               153               6/2/2019               672
#
#      number_of_reviews_ltm first_review  last_review  review_scores_rating  \
# id
# 958                     56    7/23/2009    5/16/2019                  97.0
# 7918                     0    8/31/2009   11/21/2016                  85.0
# 8142                     1     9/8/2014    9/12/2018                  93.0
# 8339                     1    9/25/2009    8/11/2018                  97.0
# 8739                    93     8/1/2009    5/21/2019                  98.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# id
# 958                     10.0                       10.0
# 7918                     8.0                        8.0
# 8142                     9.0                        9.0
# 8339                    10.0                       10.0
# 8739                    10.0                       10.0
#
#       review_scores_checkin  review_scores_communication  \
# id
# 958                    10.0                         10.0
# 7918                    9.0                          9.0
# 8142                   10.0                         10.0
# 8339                   10.0                         10.0
# 8739                   10.0                         10.0
#
#       review_scores_location  review_scores_value      license  \
# id
# 958                     10.0                  9.0  STR-0001256
# 7918                     9.0                  8.0          NaN
# 8142                     9.0                  9.0          NaN
# 8339                    10.0                  9.0  STR-0000264
# 8739                    10.0                 10.0  STR-0000028
#
#      instant_bookable  calculated_host_listings_count  \
# id
# 958                 t                               1
# 7918                f                               9
# 8142                f                               9
# 8339                f                               2
# 8739                t                               2
#
#       calculated_host_listings_count_entire_homes  \
# id
# 958                                             1
# 7918                                            0
# 8142                                            0
# 8339                                            2
# 8739                                            0
#
#       calculated_host_listings_count_private_rooms  \
# id
# 958                                              0
# 7918                                             9
# 8142                                             9
# 8339                                             0
# 8739                                             2
#
#       calculated_host_listings_count_shared_rooms reviews_per_month
# id
# 958                                             0              1.60
# 7918                                            0              0.14
# 8142                                            0              0.14
# 8339                                            0              0.23
# 8739                                            0              5.61
#
# [5 rows x 72 columns]

# %%
# Dropping columns will not to be use that consists of non value added colums, null columns and NaN value columns

# %%
# url, hostname and some other columns are not useful in predicting price and can be dropped
initial_drop = ['listing_url', 'scrape_id', 'last_scraped', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_id', 'host_url', 'host_name', 'host_location', 'host_about', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_verifications', 'calendar_last_scraped']
df = ab_df.drop(initial_drop, axis=1)

# %%
df.head()
# Out:
#      host_since  host_response_time host_response_rate host_acceptance_rate  \
# id
# 958   7/31/2008  within a few hours               100%                  NaN
# 7918  6/17/2009  within a few hours               100%                  NaN
# 8142  6/17/2009  within a few hours               100%                  NaN
# 8339   7/2/2009      within an hour               100%                  NaN
# 8739  1/27/2009      within an hour               100%                  NaN
#
#      host_is_superhost  host_listings_count  host_total_listings_count  \
# id
# 958                  t                    1                          1
# 7918                 f                   10                         10
# 8142                 f                   10                         10
# 8339                 f                    2                          2
# 8739                 t                    2                          2
#
#      host_has_profile_pic host_identity_verified     neighbourhood  \
# id
# 958                     t                      t      Lower Haight
# 7918                    t                      t       Cole Valley
# 8142                    t                      t       Cole Valley
# 8339                    t                      t      Alamo Square
# 8739                    t                      f  Mission District
#
#      neighbourhood_cleansed  latitude  longitude is_location_exact  \
# id
# 958        Western Addition  37.76931 -122.43386                 t
# 7918         Haight Ashbury  37.76669 -122.45250                 t
# 8142         Haight Ashbury  37.76487 -122.45183                 t
# 8339       Western Addition  37.77525 -122.43637                 t
# 8739                Mission  37.75919 -122.42237                 t
#
#      property_type        room_type  accommodates bathrooms  bedrooms  beds  \
# id
# 958      Apartment  Entire home/apt             3         1       1.0   2.0
# 7918     Apartment     Private room             2         4       1.0   1.0
# 8142     Apartment     Private room             2         4       1.0   1.0
# 8339         House  Entire home/apt             5       1.5       2.0   2.0
# 8739   Condominium     Private room             3         1       1.0   2.0
#
#       bed_type                                          amenities     price  \
# id
# 958   Real Bed  {TV,Cable TV,Internet,Wifi,Kitchen,Pets live o...  $170.00
# 7918  Real Bed  {TV,Internet,Wifi,Kitchen,Free street parking,...   $65.00
# 8142  Real Bed  {TV,Internet,Wifi,Kitchen,Free street parking,...   $65.00
# 8339  Real Bed  {TV,Internet,Wifi,Kitchen,Heating,Family/kid f...  $685.00
# 8739  Real Bed  {TV,Cable TV,Internet,Wifi,Pets live on this p...  $139.00
#
#       minimum_nights  maximum_nights  minimum_minimum_nights  \
# id
# 958                1              30                     1.0
# 7918              32              60                    32.0
# 8142              32              90                    32.0
# 8339               4            1125                     4.0
# 8739               1              14                     1.0
#
#       maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# id
# 958                      1.0                    30.0                    30.0
# 7918                    32.0                    60.0                    60.0
# 8142                    32.0                    90.0                    90.0
# 8339                     4.0                  1125.0                  1125.0
# 8739                     1.0                    14.0                    14.0
#
#       minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# id
# 958                      1.0                    30.0     2 months ago
# 7918                    32.0                    60.0    19 months ago
# 8142                    32.0                    90.0    19 months ago
# 8339                     4.0                  1125.0      2 weeks ago
# 8739                     1.0                    14.0      2 weeks ago
#
#      has_availability  availability_30  availability_60  availability_90  \
# id
# 958                 t                1                3                7
# 7918                t               30               60               90
# 8142                t               11               41               71
# 8339                t               30               60               90
# 8739                t               11               38               64
#
#       availability_365  number_of_reviews  number_of_reviews_ltm first_review  \
# id
# 958                 92                192                     56    7/23/2009
# 7918               365                 17                      0    8/31/2009
# 8142               346                  8                      1     9/8/2014
# 8339                90                 27                      1    9/25/2009
# 8739               153                672                     93     8/1/2009
#
#      last_review  review_scores_rating  review_scores_accuracy  \
# id
# 958    5/16/2019                  97.0                    10.0
# 7918  11/21/2016                  85.0                     8.0
# 8142   9/12/2018                  93.0                     9.0
# 8339   8/11/2018                  97.0                    10.0
# 8739   5/21/2019                  98.0                    10.0
#
#       review_scores_cleanliness  review_scores_checkin  \
# id
# 958                        10.0                   10.0
# 7918                        8.0                    9.0
# 8142                        9.0                   10.0
# 8339                       10.0                   10.0
# 8739                       10.0                   10.0
#
#       review_scores_communication  review_scores_location  \
# id
# 958                          10.0                    10.0
# 7918                          9.0                     9.0
# 8142                         10.0                     9.0
# 8339                         10.0                    10.0
# 8739                         10.0                    10.0
#
#       review_scores_value      license instant_bookable  \
# id
# 958                   9.0  STR-0001256                t
# 7918                  8.0          NaN                f
# 8142                  9.0          NaN                f
# 8339                  9.0  STR-0000264                f
# 8739                 10.0  STR-0000028                t
#
#       calculated_host_listings_count  \
# id
# 958                                1
# 7918                               9
# 8142                               9
# 8339                               2
# 8739                               2
#
#       calculated_host_listings_count_entire_homes  \
# id
# 958                                             1
# 7918                                            0
# 8142                                            0
# 8339                                            2
# 8739                                            0
#
#       calculated_host_listings_count_private_rooms  \
# id
# 958                                              0
# 7918                                             9
# 8142                                             9
# 8339                                             0
# 8739                                             2
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 958                                             0               1.60
# 7918                                            0               0.14
# 8142                                            0               0.14
# 8339                                            0               0.23
# 8739                                            0               5.61

# %%
# df column summary

# %%
df.isna().sum()
# Out:
# host_since                                        0
# host_response_time                             1986
#                                                ...
# calculated_host_listings_count_shared_rooms       0
# reviews_per_month                              2401
# Length: 55, dtype: int64

# %%
print(f"The dataset contains {len(df)} SF Airbnb listings")
pd.set_option('display.max_columns', len(df.columns))
pd.set_option('display.max_rows', 5)
df.head()
# Out:
# The dataset contains 12616 SF Airbnb listings
#      host_since  host_response_time host_response_rate host_acceptance_rate  \
# id
# 958   7/31/2008  within a few hours               100%                  NaN
# 7918  6/17/2009  within a few hours               100%                  NaN
# 8142  6/17/2009  within a few hours               100%                  NaN
# 8339   7/2/2009      within an hour               100%                  NaN
# 8739  1/27/2009      within an hour               100%                  NaN
#
#      host_is_superhost  host_listings_count  host_total_listings_count  \
# id
# 958                  t                    1                          1
# 7918                 f                   10                         10
# 8142                 f                   10                         10
# 8339                 f                    2                          2
# 8739                 t                    2                          2
#
#      host_has_profile_pic host_identity_verified     neighbourhood  \
# id
# 958                     t                      t      Lower Haight
# 7918                    t                      t       Cole Valley
# 8142                    t                      t       Cole Valley
# 8339                    t                      t      Alamo Square
# 8739                    t                      f  Mission District
#
#      neighbourhood_cleansed  latitude  longitude is_location_exact  \
# id
# 958        Western Addition  37.76931 -122.43386                 t
# 7918         Haight Ashbury  37.76669 -122.45250                 t
# 8142         Haight Ashbury  37.76487 -122.45183                 t
# 8339       Western Addition  37.77525 -122.43637                 t
# 8739                Mission  37.75919 -122.42237                 t
#
#      property_type        room_type  accommodates bathrooms  bedrooms  beds  \
# id
# 958      Apartment  Entire home/apt             3         1       1.0   2.0
# 7918     Apartment     Private room             2         4       1.0   1.0
# 8142     Apartment     Private room             2         4       1.0   1.0
# 8339         House  Entire home/apt             5       1.5       2.0   2.0
# 8739   Condominium     Private room             3         1       1.0   2.0
#
#       bed_type                                          amenities     price  \
# id
# 958   Real Bed  {TV,Cable TV,Internet,Wifi,Kitchen,Pets live o...  $170.00
# 7918  Real Bed  {TV,Internet,Wifi,Kitchen,Free street parking,...   $65.00
# 8142  Real Bed  {TV,Internet,Wifi,Kitchen,Free street parking,...   $65.00
# 8339  Real Bed  {TV,Internet,Wifi,Kitchen,Heating,Family/kid f...  $685.00
# 8739  Real Bed  {TV,Cable TV,Internet,Wifi,Pets live on this p...  $139.00
#
#       minimum_nights  maximum_nights  minimum_minimum_nights  \
# id
# 958                1              30                     1.0
# 7918              32              60                    32.0
# 8142              32              90                    32.0
# 8339               4            1125                     4.0
# 8739               1              14                     1.0
#
#       maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# id
# 958                      1.0                    30.0                    30.0
# 7918                    32.0                    60.0                    60.0
# 8142                    32.0                    90.0                    90.0
# 8339                     4.0                  1125.0                  1125.0
# 8739                     1.0                    14.0                    14.0
#
#       minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# id
# 958                      1.0                    30.0     2 months ago
# 7918                    32.0                    60.0    19 months ago
# 8142                    32.0                    90.0    19 months ago
# 8339                     4.0                  1125.0      2 weeks ago
# 8739                     1.0                    14.0      2 weeks ago
#
#      has_availability  availability_30  availability_60  availability_90  \
# id
# 958                 t                1                3                7
# 7918                t               30               60               90
# 8142                t               11               41               71
# 8339                t               30               60               90
# 8739                t               11               38               64
#
#       availability_365  number_of_reviews  number_of_reviews_ltm first_review  \
# id
# 958                 92                192                     56    7/23/2009
# 7918               365                 17                      0    8/31/2009
# 8142               346                  8                      1     9/8/2014
# 8339                90                 27                      1    9/25/2009
# 8739               153                672                     93     8/1/2009
#
#      last_review  review_scores_rating  review_scores_accuracy  \
# id
# 958    5/16/2019                  97.0                    10.0
# 7918  11/21/2016                  85.0                     8.0
# 8142   9/12/2018                  93.0                     9.0
# 8339   8/11/2018                  97.0                    10.0
# 8739   5/21/2019                  98.0                    10.0
#
#       review_scores_cleanliness  review_scores_checkin  \
# id
# 958                        10.0                   10.0
# 7918                        8.0                    9.0
# 8142                        9.0                   10.0
# 8339                       10.0                   10.0
# 8739                       10.0                   10.0
#
#       review_scores_communication  review_scores_location  \
# id
# 958                          10.0                    10.0
# 7918                          9.0                     9.0
# 8142                         10.0                     9.0
# 8339                         10.0                    10.0
# 8739                         10.0                    10.0
#
#       review_scores_value      license instant_bookable  \
# id
# 958                   9.0  STR-0001256                t
# 7918                  8.0          NaN                f
# 8142                  9.0          NaN                f
# 8339                  9.0  STR-0000264                f
# 8739                 10.0  STR-0000028                t
#
#       calculated_host_listings_count  \
# id
# 958                                1
# 7918                               9
# 8142                               9
# 8339                               2
# 8739                               2
#
#       calculated_host_listings_count_entire_homes  \
# id
# 958                                             1
# 7918                                            0
# 8142                                            0
# 8339                                            2
# 8739                                            0
#
#       calculated_host_listings_count_private_rooms  \
# id
# 958                                              0
# 7918                                             9
# 8142                                             9
# 8339                                             0
# 8739                                             2
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 958                                             0               1.60
# 7918                                            0               0.14
# 8142                                            0               0.14
# 8339                                            0               0.23
# 8739                                            0               5.61

# %%
lat_long = df[['latitude', 'longitude']]

# %%
df.drop(['latitude', 'longitude', 'neighbourhood','is_location_exact'], axis=1, inplace=True)

# %%
sum((df.minimum_nights == df.minimum_minimum_nights) == False)
# Out:
# 609

# %%
# We can drop this features
df.drop(['host_acceptance_rate','minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm'], axis=1, inplace=True)

# %%
# Replacing columns with f/t with 0/1
df.replace({'f': 0, 't': 1}, inplace=True)

# %%
df.head()
# Out:
#      host_since  host_response_time host_response_rate  host_is_superhost  \
# id
# 958   7/31/2008  within a few hours               100%                  1
# 7918  6/17/2009  within a few hours               100%                  0
# 8142  6/17/2009  within a few hours               100%                  0
# 8339   7/2/2009      within an hour               100%                  0
# 8739  1/27/2009      within an hour               100%                  1
#
#       host_listings_count  host_total_listings_count  host_has_profile_pic  \
# id
# 958                     1                          1                     1
# 7918                   10                         10                     1
# 8142                   10                         10                     1
# 8339                    2                          2                     1
# 8739                    2                          2                     1
#
#       host_identity_verified neighbourhood_cleansed property_type  \
# id
# 958                        1       Western Addition     Apartment
# 7918                       1         Haight Ashbury     Apartment
# 8142                       1         Haight Ashbury     Apartment
# 8339                       1       Western Addition         House
# 8739                       0                Mission   Condominium
#
#             room_type  accommodates bathrooms  bedrooms  beds  bed_type  \
# id
# 958   Entire home/apt             3         1       1.0   2.0  Real Bed
# 7918     Private room             2         4       1.0   1.0  Real Bed
# 8142     Private room             2         4       1.0   1.0  Real Bed
# 8339  Entire home/apt             5       1.5       2.0   2.0  Real Bed
# 8739     Private room             3         1       1.0   2.0  Real Bed
#
#                                               amenities     price  \
# id
# 958   {TV,Cable TV,Internet,Wifi,Kitchen,Pets live o...  $170.00
# 7918  {TV,Internet,Wifi,Kitchen,Free street parking,...   $65.00
# 8142  {TV,Internet,Wifi,Kitchen,Free street parking,...   $65.00
# 8339  {TV,Internet,Wifi,Kitchen,Heating,Family/kid f...  $685.00
# 8739  {TV,Cable TV,Internet,Wifi,Pets live on this p...  $139.00
#
#       minimum_nights  maximum_nights calendar_updated  has_availability  \
# id
# 958                1              30     2 months ago                 1
# 7918              32              60    19 months ago                 1
# 8142              32              90    19 months ago                 1
# 8339               4            1125      2 weeks ago                 1
# 8739               1              14      2 weeks ago                 1
#
#       availability_30  availability_60  availability_90  availability_365  \
# id
# 958                 1                3                7                92
# 7918               30               60               90               365
# 8142               11               41               71               346
# 8339               30               60               90                90
# 8739               11               38               64               153
#
#       number_of_reviews  number_of_reviews_ltm first_review last_review  \
# id
# 958                 192                     56    7/23/2009   5/16/2019
# 7918                 17                      0    8/31/2009  11/21/2016
# 8142                  8                      1     9/8/2014   9/12/2018
# 8339                 27                      1    9/25/2009   8/11/2018
# 8739                672                     93     8/1/2009   5/21/2019
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# id
# 958                   97.0                    10.0                       10.0
# 7918                  85.0                     8.0                        8.0
# 8142                  93.0                     9.0                        9.0
# 8339                  97.0                    10.0                       10.0
# 8739                  98.0                    10.0                       10.0
#
#       review_scores_checkin  review_scores_communication  \
# id
# 958                    10.0                         10.0
# 7918                    9.0                          9.0
# 8142                   10.0                         10.0
# 8339                   10.0                         10.0
# 8739                   10.0                         10.0
#
#       review_scores_location  review_scores_value      license  \
# id
# 958                     10.0                  9.0  STR-0001256
# 7918                     9.0                  8.0          NaN
# 8142                     9.0                  9.0          NaN
# 8339                    10.0                  9.0  STR-0000264
# 8739                    10.0                 10.0  STR-0000028
#
#       instant_bookable  calculated_host_listings_count  \
# id
# 958                  1                               1
# 7918                 0                               9
# 8142                 0                               9
# 8339                 0                               2
# 8739                 1                               2
#
#       calculated_host_listings_count_entire_homes  \
# id
# 958                                             1
# 7918                                            0
# 8142                                            0
# 8339                                            2
# 8739                                            0
#
#       calculated_host_listings_count_private_rooms  \
# id
# 958                                              0
# 7918                                             9
# 8142                                             9
# 8339                                             0
# 8739                                             2
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 958                                             0               1.60
# 7918                                            0               0.14
# 8142                                            0               0.14
# 8339                                            0               0.23
# 8739                                            0               5.61

# %% [markdown]
# # Separate numerical and boolean categoris and plot histogram to see value needed in data

# %%
# lets separate numerical and boolean categoris and plot histogram to see value needed in data and can help identify important columns
df.hist(figsize=(15,15));

# %%
# We can clearly see that there are many columns contain one category and we can drop those columns contain only one category
df.drop(['has_availability', 'host_has_profile_pic'], axis=1, inplace=True)

# %%
from datetime import datetime

# %%
# Convert to datetime
df.host_since = pd.to_datetime(df.host_since) 

# Calculate the number of days
df['host_days_active'] = (datetime(2019, 6, 2) - df.host_since).astype('timedelta64[D]')

# Printing mean and median
print("Mean days as host:", round(df['host_days_active'].mean(),0))
print("Median days as host:", df['host_days_active'].median())

# Replacing null values with the median
df.host_days_active.fillna(df.host_days_active.median(), inplace=True)
# Out:
# Mean days as host: 1631.0
# Median days as host: 1698.0

# %%
# Reading data in excel we can see tha host_response_time is unknown for so many listings
print("Null values:", df.host_response_time.isna().sum())
print(f"Proportion: {round((df.host_response_time.isna().sum()/len(df))*100, 1)}%")
# Out:
# Null values: 1986
# Proportion: 15.7%

# %%
df.host_response_time.value_counts(normalize=True)
# Out:
# within an hour        0.637159
# within a few hours    0.245626
# within a day          0.094920
# a few days or more    0.022295
# Name: host_response_time, dtype: float64

# %%
# Now we can move on to other column host_response_rate showing unknown blanks same as host_response_time
# and we can print host_response_rate is unknown for so many listings
print("Null values:", df.host_response_rate.isna().sum())
print(f"Proportion: {round((df.host_response_rate.isna().sum()/len(df))*100, 1)}%")
# Out:
# Null values: 1986
# Proportion: 15.7%

# %%
# Removing the % sign from the host_response_rate string and converting to an integer
df.host_response_rate = df.host_response_rate.str[:-1].astype('float64')

print("Mean host response rate:", round(df['host_response_rate'].mean(),0))
print("Median host response rate:", df['host_response_rate'].median())
print(f"Proportion of 100% host response rates: {round(((df.host_response_rate == 100.0).sum()/df.host_response_rate.count())*100,1)}%")
# Out:
# Mean host response rate: 95.0
# Median host response rate: 100.0
# Proportion of 100% host response rates: 75.7%

# %%
# Response rate is showing great results and we can see creating histogram for better graphical represntation, 
# the first step is to “bin” the range of values — that is, divide the entire range of values into a series of intervals
# and then count how many values fall into each interval. Alsowe have to remove or replace nulls.

df.host_response_rate = pd.cut(df.host_response_rate, bins=[0, 50, 90, 99, 100], labels=['0-49%', '50-89%', '90-99%', '100%'], include_lowest=True)

# we have to Convert to string to replace null
df.host_response_rate = df.host_response_rate.astype('str')

# Replace nulls with 'unknown'
df.host_response_rate.replace('nan', 'unknown', inplace=True)

# Category counts
df.host_response_rate.value_counts()
# Out:
# 100%       8049
# unknown    1986
# 90-99%     1200
# 50-89%     1095
# 0-49%       286
# Name: host_response_rate, dtype: int64

# %%
df.host_response_rate.hist(figsize=(5,5));

# %%
df.head()
# Out:
#      host_since  host_response_time host_response_rate  host_is_superhost  \
# id
# 958  2008-07-31  within a few hours               100%                  1
# 7918 2009-06-17  within a few hours               100%                  0
# 8142 2009-06-17  within a few hours               100%                  0
# 8339 2009-07-02      within an hour               100%                  0
# 8739 2009-01-27      within an hour               100%                  1
#
#       host_listings_count  host_total_listings_count  host_identity_verified  \
# id
# 958                     1                          1                       1
# 7918                   10                         10                       1
# 8142                   10                         10                       1
# 8339                    2                          2                       1
# 8739                    2                          2                       0
#
#      neighbourhood_cleansed property_type        room_type  accommodates  \
# id
# 958        Western Addition     Apartment  Entire home/apt             3
# 7918         Haight Ashbury     Apartment     Private room             2
# 8142         Haight Ashbury     Apartment     Private room             2
# 8339       Western Addition         House  Entire home/apt             5
# 8739                Mission   Condominium     Private room             3
#
#      bathrooms  bedrooms  beds  bed_type  \
# id
# 958          1       1.0   2.0  Real Bed
# 7918         4       1.0   1.0  Real Bed
# 8142         4       1.0   1.0  Real Bed
# 8339       1.5       2.0   2.0  Real Bed
# 8739         1       1.0   2.0  Real Bed
#
#                                               amenities     price  \
# id
# 958   {TV,Cable TV,Internet,Wifi,Kitchen,Pets live o...  $170.00
# 7918  {TV,Internet,Wifi,Kitchen,Free street parking,...   $65.00
# 8142  {TV,Internet,Wifi,Kitchen,Free street parking,...   $65.00
# 8339  {TV,Internet,Wifi,Kitchen,Heating,Family/kid f...  $685.00
# 8739  {TV,Cable TV,Internet,Wifi,Pets live on this p...  $139.00
#
#       minimum_nights  maximum_nights calendar_updated  availability_30  \
# id
# 958                1              30     2 months ago                1
# 7918              32              60    19 months ago               30
# 8142              32              90    19 months ago               11
# 8339               4            1125      2 weeks ago               30
# 8739               1              14      2 weeks ago               11
#
#       availability_60  availability_90  availability_365  number_of_reviews  \
# id
# 958                 3                7                92                192
# 7918               60               90               365                 17
# 8142               41               71               346                  8
# 8339               60               90                90                 27
# 8739               38               64               153                672
#
#       number_of_reviews_ltm first_review last_review  review_scores_rating  \
# id
# 958                      56    7/23/2009   5/16/2019                  97.0
# 7918                      0    8/31/2009  11/21/2016                  85.0
# 8142                      1     9/8/2014   9/12/2018                  93.0
# 8339                      1    9/25/2009   8/11/2018                  97.0
# 8739                     93     8/1/2009   5/21/2019                  98.0
#
#       review_scores_accuracy  review_scores_cleanliness  \
# id
# 958                     10.0                       10.0
# 7918                     8.0                        8.0
# 8142                     9.0                        9.0
# 8339                    10.0                       10.0
# 8739                    10.0                       10.0
#
#       review_scores_checkin  review_scores_communication  \
# id
# 958                    10.0                         10.0
# 7918                    9.0                          9.0
# 8142                   10.0                         10.0
# 8339                   10.0                         10.0
# 8739                   10.0                         10.0
#
#       review_scores_location  review_scores_value      license  \
# id
# 958                     10.0                  9.0  STR-0001256
# 7918                     9.0                  8.0          NaN
# 8142                     9.0                  9.0          NaN
# 8339                    10.0                  9.0  STR-0000264
# 8739                    10.0                 10.0  STR-0000028
#
#       instant_bookable  calculated_host_listings_count  \
# id
# 958                  1                               1
# 7918                 0                               9
# 8142                 0                               9
# 8339                 0                               2
# 8739                 1                               2
#
#       calculated_host_listings_count_entire_homes  \
# id
# 958                                             1
# 7918                                            0
# 8142                                            0
# 8339                                            2
# 8739                                            0
#
#       calculated_host_listings_count_private_rooms  \
# id
# 958                                              0
# 7918                                             9
# 8142                                             9
# 8339                                             0
# 8739                                             2
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month  \
# id
# 958                                             0               1.60
# 7918                                            0               0.14
# 8142                                            0               0.14
# 8339                                            0               0.23
# 8739                                            0               5.61
#
#       host_days_active
# id
# 958             3958.0
# 7918            3637.0
# 8142            3637.0
# 8339            3622.0
# 8739            3778.0

# %%
# reviewing property data to classify and replacing to minimize names of different property
df.property_type.value_counts()
# Out:
# Apartment               2336
# Entire rental unit      1881
#                         ...
# Cabin                      1
# Shared room in hotel       1
# Name: property_type, Length: 79, dtype: int64

# %%
# minimizing total different variables and repalcing names which are similar to House or apartments
df.property_type.replace({
    'Townhouse': 'House',
    'Entire rental unit':'House',
    'Condominium': 'Apartment',
    'Hotel': 'Apartment',
    'Guest suite': 'House',
    'Timeshare': 'House',
    'In-law': 'House',
    }, inplace=True)

# %%
# Now to see only Apartment and House and Replace other categories with 'other'
df.loc[~df.property_type.isin(['House', 'Apartment']), 'property_type'] = 'Other'

# %%
df.property_type.value_counts()
# Out:
# Other        5143
# House        4323
# Apartment    3150
# Name: property_type, dtype: int64

# %%
df.bed_type.value_counts()
# Out:
# Real Bed         12555
# Futon               27
# Pull-out Sofa       20
# Airbed               9
# Couch                5
# Name: bed_type, dtype: int64

# %%
# we can drop bed_type as most of them has value = Real Bed
df.drop('bed_type', axis=1, inplace=True)

# %% [markdown]
# # Amenities are important in this business , check Emenities by listing and separate and join list of amenities

# %%
df.amenities[:1].values
# Out:
# array(['{TV,Cable TV,Internet,Wifi,Kitchen,Pets live on this property,Dog(s),Heating,Family/kid friendly,Washer,Dryer,Smoke detector,Carbon monoxide detector,First aid kit,Essentials,Shampoo,24-hour check-in,Hangers,Hair dryer,Iron,Laptop friendly workspace,Self check-in,Keypad,Private entrance,Pack ‚Äôn Play/travel crib,Room-darkening shades}'],
#       dtype=object)

# %%
# Creating a set of all possible amenities
amenities_list = list(df.amenities)
amenities_list_string = " ".join(amenities_list)
amenities_list_string = amenities_list_string.replace('{', '')
amenities_list_string = amenities_list_string.replace('}', ',')
amenities_list_string = amenities_list_string.replace('"', '')
amenities_set = [x.strip() for x in amenities_list_string.split(',')]
amenities_set = set(amenities_set)
amenities_set
# Out:
# {'',
#  'Wolf oven',
#  'Paid parking off premises] [Paid parking garage off premises',
#  '32\\ HDTV with Roku',
#  'TV with Roku',
#  'Memory foam mattress',
#  'Hangers] [Free street parking',
#  'Wheelchair accessible',
#  'various conditioner',
#  '40\\ HDTV with Roku',
#  'Essentials',
#  'Shaikai conditioner',
#  'ROIL toiletries',
#  'typically hotel samples body soap',
#  'Sun loungers',
#  'toilet',
#  'Sound system',
#  'Garage parking',
#  'Shared gym nearby',
#  'Wide entrance',
#  'closet',
#  'Dedicated workspace: desk and office chair',
#  'Paid parking off premises] [Long term stays allowed',
#  'Sonos sound system with aux',
#  'Limited housekeeping \\u2014',
#  'Iron] [Pets allowed',
#  'Dedicated workspace: desk and table',
#  'High chair] [Game console',
#  'Frigidaire 5.6cf with separate freezer refrigerator',
#  'Blomberg refrigerator',
#  'sony sound system',
#  'full size refrigerator',
#  'EO shampoo',
#  "Mrs. Meyer's Clean Day Body Wash body soap",
#  'Private gym in building',
#  'Mini fridge] [Microwave',
#  '45\\ HDTV with premium cable',
#  'Ikea body soap',
#  'Coffee maker] [Dedicated workspace: office chair and desk',
#  'Taotronics Bluetooth sound system] [Essentials',
#  'Dedicated workspace: monitor',
#  '32\\ TV with Chromecast',
#  'Iron] [Dryer \\u2013 In building',
#  'Baby safety gates',
#  '39\\ HDTV with Chromecast',
#  'Paid parking on premises \\u2013 100 spaces',
#  'Walk-in shower',
#  'Clothing storage] [Free street parking',
#  'Lock on bedroom door] [Microwave',
#  'Beach view',
#  'TV] [Game console',
#  'TV] [Cleaning products',
#  'Lever 2000 body soap',
#  'UNKNOWN',
#  '45\\ HDTV',
#  'Various shampoo',
#  'Paid parking off premises] [Outdoor dining area',
#  'OGX conditioner',
#  'Off-Brand refrigerator',
#  'Dedicated workspace] [Microwave',
#  'small fridge with small freezer for ice cubes refrigerator',
#  'Board games',
#  'Clothing storage] [Microwave',
#  'Bertazonni stainless steel gas stove',
#  'Electric oven',
#  '40\\ HDTV with standard cable',
#  'natural conditioner',
#  'Dedicated workspace: desk',
#  'Free driveway parking on premises',
#  'Convection Oven stainless steel oven',
#  'Shower gel] [Free street parking',
#  'Dishes and silverware] [Carbon monoxide alarm',
#  'Lounge area',
#  'GE gas stove',
#  'Portable fans',
#  'Host greets you] [Outdoor dining area',
#  'Clothing storage] [Carbon monoxide alarm',
#  'Auyervedic Soap body soap',
#  'Mudroom',
#  'Day bed',
#  'Long term stays allowed',
#  'Natural  conditioner',
#  'Dog(s)',
#  'Doorman',
#  'Single Electric Burner electric stove',
#  'Aveeno body soap',
#  'Frigidare stainless steel stove',
#  'High chair] [Cleaning products',
#  '70\\ HDTV with Netflix',
#  'Dishes and silverware] [Essentials',
#  'Oven] [Carbon monoxide alarm',
#  '36\\ TV',
#  'Dedicated workspace] [Essentials',
#  'organic products',
#  'High chair] [Fire extinguisher',
#  'Dishes and silverware] [Long term stays allowed] [Hot water kettle',
#  'Dove conditioner',
#  'Clothing storage] [Cleaning products',
#  'Pre-amp. Amp',
#  'Bose SoundTouch Bluetooth sound system',
#  'Coffee maker] [Gas stove',
#  '120\\ TV with Amazon Prime Video',
#  'Body wash body soap',
#  'Air conditioning',
#  'Host greets you] [Outdoor furniture',
#  'Bidet',
#  'High chair] [Breakfast',
#  '32\\ TV with Roku',
#  'Shared hot tub] [Hot water kettle',
#  'BBQ grill',
#  'Roku',
#  'Outdoor furniture',
#  'Nessus body soap',
#  'Single level home] [Outdoor furniture',
#  'DVD player sound system',
#  'Elizabeth W conditioner',
#  'Bosch stainless steel oven',
#  'General Electric stainless steel gas stove',
#  'Wifi] [Dedicated workspace',
#  'Heating] [Free street parking',
#  '40\\ HDTV with HBO Max',
#  'Bertazzoni; two 30\\ refrigerators side by side and a 30 bottle wine fridge refrigerator',
#  'Puracy shampoo',
#  'Private living room',
#  'Heating skillet stove',
#  'viking stainless steel oven',
#  'Stainless steel oven',
#  'High chair] [Portable heater',
#  'Accessible-height toilet',
#  'Shower gel] [Fire extinguisher',
#  'Clothing storage: closet and dresser',
#  '50\\ HDTV with Roku',
#  'Sun deck',
#  'Heating] [Gym',
#  'Herbal Essence shampoo',
#  "Rudy's \\u00b7\\u00a0Ace Hotel body soap",
#  'World Amenities conditioner] [Fire extinguisher',
#  'Samsung refrigerator',
#  'Thermador refrigerator',
#  'Coffee maker] [Paid parking garage off premises',
#  'Varies shampoo',
#  'Keypad] [Free street parking',
#  'Caress body soap',
#  'TV with standard cable] [Full kitchen',
#  'Stove',
#  'Pro series oven',
#  'TV with standard cable] [Breakfast',
#  'pantene shampoo',
#  'Paid washer \\u2013 In building',
#  'Wet bar',
#  'Self check-in] [Dedicated workspace',
#  'Self check-in] [BBQ grill',
#  'Induction stove',
#  'Free dryer \\u2013 In unit] [Essentials',
#  "o'keefe and merritt gas stove",
#  'and monitor',
#  'Wifi] [BBQ grill',
#  'Self check-in] [Board games',
#  'Bose & Amazon Devices  sound system with Bluetooth and aux',
#  'Dedicated workspace',
#  '2 Burner Glass Stovetop stove',
#  'Yamaha 7.2 sound system with Bluetooth and aux',
#  'Hot tub] [Free street parking',
#  'Everyone body soap',
#  'Breville Toaster Oven oven',
#  'Generic conditioner] [Fire extinguisher',
#  'Kirkland Natural Body Wash (citrus) body soap',
#  'Amazon Echo Plus sound system with Bluetooth and aux',
#  'Clothing storage] [BBQ grill',
#  'I usually have Hugh end hotel body soap (Ritz) body soap',
#  'standard cable] [Free street parking',
#  'Clothing storage: wardrobe and closet] [Microwave',
#  'Children\\u2019s books and toys for ages 0-2 years old and 2-5 years old',
#  'multiple brands shampoo',
#  'Shared gym',
#  'Whirlpool gas stove',
#  'Private hot tub] [Essentials',
#  'Safety card',
#  'Host greets you',
#  'Paid parking off premises',
#  'Luggage dropoff allowed] [Fire extinguisher',
#  'Stove] [Outdoor furniture',
#  'Single level home] [Carbon monoxide alarm',
#  'Game console: Nintendo Switch and PS4',
#  'Fenced garden or backyard',
#  'Wide hallways',
#  'Countertop Toaster Oven oven',
#  '58\\ HDTV with Amazon Prime Video',
#  'Freezer] [Microwave',
#  'Nexxus conditioner] [Hot water kettle',
#  'Shower chair',
#  'Dove Body Wash body soap',
#  'Wifi \\u2013 350 Mbps] [BBQ grill',
#  'Smart TV',
#  'Single level home',
#  'Outlet covers',
#  'portable stove electric stove',
#  'Bikes',
#  'Coffee maker] [Gym',
#  'Frigidare refrigerator] [Carbon monoxide alarm',
#  'Oven] [Essentials',
#  'hot plate and microwave electric stove',
#  'Blue Star Six (6) Burner stainless steel stove',
#  '40\\ HDTV with Netflix',
#  '56\\ HDTV with Amazon Prime Video',
#  'Free parking on premises] [Free street parking',
#  'Pantene shampoo and conditioner conditioner',
#  'Coffee maker',
#  'Dr Bronners \\u201call in one\\u201d body soap',
#  'Free parking on premises] [Microwave',
#  'Baby bath',
#  'Thermador stainless steel gas stove',
#  'Breakfast table',
#  'EO body soap',
#  'Mini fridge] [Paid parking garage off premises',
#  'Olay shampoo',
#  'and office chair',
#  'Pantene 2-1 shampoo',
#  'Lock on bedroom door] [Fire extinguisher',
#  'Amazon Alexa Throughout Bluetooth sound system',
#  'Bidet] [Free street parking',
#  'Hot tub] [Essentials',
#  'First aid kit',
#  'Clothing storage: walk-in closet',
#  'Central heating',
#  'Lock on bedroom door] [Free street parking',
#  'Dedicated workspace] [Free street parking',
#  'LG stainless steel oven',
#  'HDTV with Roku',
#  'Iron] [Paid parking lot on premises \\u2013 1 space',
#  'TV] [Essentials',
#  'Dacor refrigerator',
#  "Trader Joe's Nourish Spa Conditioner conditioner",
#  'Crib] [Dryer',
#  'GE refrigerator',
#  'Paid dryer \\u2013 In building',
#  'TV] [Breakfast',
#  'Free residential garage on premises \\u2013 48 spaces',
#  'Blue Star stainless steel gas stove',
#  'Wifi \\u2013 400 Mbps',
#  'Dual vanity',
#  'Room service',
#  'Keypad] [Microwave',
#  'Paid washer',
#  'mini fridge refrigerator',
#  'EO lavender  body soap',
#  'translation missing: en.hosting_amenity_50',
#  'Neutrogena body soap',
#  'Shared fenced garden or backyard',
#  'Wifi \\u2013 159 Mbps',
#  'Host greets you] [Single level home',
#  'Free driveway parking on premises \\u2013 1 space',
#  'Kirkland Natural Citrus Bodywash body soap',
#  '44\\ HDTV with Amazon Prime Video',
#  'Private patio or balcony',
#  'wardrobe',
#  'Wifi \\u2013 700 Mbps',
#  'Gaggenau convection oven wall mounted oven',
#  'Herbal Essence body soap',
#  'Breakfast bar',
#  'Private hot tub] [Carbon monoxide alarm',
#  'Jennair refrigerator',
#  'Nexxus conditioner',
#  'Other pet(s)',
#  'Lather body soap',
#  'Whirlpool stainless steel electric stove',
#  'Nexxus shampoo',
#  'dresser',
#  'Pets live on this property',
#  'Portable Stove electric stove',
#  'Iron] [Dedicated workspace: office chair and desk',
#  'Nexxus  shampoo',
#  'Dove neutral body soap',
#  'Luggage dropoff allowed] [Outdoor dining area',
#  '65\\ HDTV with Apple TV',
#  'Mini fridge] [Outdoor furniture',
#  'Clothing storage] [Dryer',
#  'Bathtub with bath chair',
#  'whirlpool gas stove',
#  'Keypad] [Clothing storage: closet and walk-in closet',
#  'Wifi \\u2013 350 Mbps] [Carbon monoxide alarm',
#  'Electric stove] [Free street parking',
#  'Single level home] [BBQ grill',
#  'Free carport on premises \\u2013 1 space',
#  'Bertazzoni',
#  'Clothing storage] [Full kitchen',
#  '50\\ HDTV with Amazon Prime Video',
#  'Aveda body soap',
#  'Bluetooth sound system] [Cleaning products',
#  'Wifi \\u2013 93 Mbps',
#  'Outdoor dining area',
#  'Children\\u2019s books and toys for ages 2-5 years old',
#  'DVD player',
#  'Wifi \\u2013 71 Mbps',
#  'Room service] [Hot water kettle',
#  'Mane and tail  conditioner',
#  'Carbon monoxide alarm] [Fire extinguisher',
#  'Wide doorway to guest bathroom',
#  'Heating] [Carbon monoxide alarm',
#  'We provide shampoo and conditioner conditioner',
#  'Ironing Board',
#  'Luggage dropoff allowed',
#  'Pantene 2-1 conditioner',
#  'Gas oven',
#  'Marantz Bluetooth sound system',
#  'Sony 5.1 Surround Sound sound system with Bluetooth and aux',
#  'Sonos with Alexa Bluetooth sound system',
#  '36\\ HDTV with Amazon Prime Video',
#  'LG refrigerator',
#  'Free driveway parking on premises \\u2013 2 spaces',
#  'Wifi] [Free street parking',
#  'Paid parking off premises] [Microwave',
#  'Marshall sound system with Bluetooth and aux',
#  'Bed linens',
#  'Paid parking lot on premises \\u2013 1 space',
#  'HDTV with Netflix',
#  'Private entrance] [Free street parking',
#  'Amazon Echo',
#  '45\\ HDTV with Roku',
#  'Kitchenette] [Fire extinguisher',
#  'Bath & Body Works conditioner',
#  'desk',
#  '65\\ HDTV with Netflix',
#  'Coffee maker] [Sony sound system with aux',
#  'Buzzer/wireless intercom',
#  'Dr bronners body soap',
#  'Air conditioning] [Hot water kettle',
#  '55\\ HDTV',
#  '30\\Steam Oven and 36\\ Oven  stainless steel oven',
#  'Keurig coffee machine',
#  "vintage O'Keefe and Merritt gas stove",
#  'Free driveway parking on premises \\u2013 4 spaces] [Free street parking',
#  'Dove  body soap',
#  "o'keefe and merritt oven",
#  'High chair] [Board games',
#  'Self check-in] [Dryer',
#  'Home theater',
#  'Bread maker',
#  'Dedicated workspace: desk] [Free street parking',
#  'Host greets you] [Dryer',
#  'Wifi \\u2013 130 Mbps',
#  'Outlier sound system with Bluetooth and aux',
#  'Thermidor gas stove',
#  'TV with standard cable] [Cleaning products',
#  '65\\ HDTV',
#  'Mini fridge] [Long term stays allowed',
#  'Crib] [Essentials',
#  '48\\ HDTV with Amazon Prime Video',
#  'Yamaha Bluetooth sound system',
#  'Free parking on premises] [Fire extinguisher',
#  'HDTV] [Fire extinguisher',
#  'Heating] [Dryer',
#  'Jason shampoo',
#  'AVEDA Rosemary Mint body soap',
#  'Tressemme shampoo',
#  'Fresh Aloe Massage Bar formulated with Organic Oatmeal body soap',
#  'Clothing storage: wardrobe',
#  'Coffee maker] [Board games',
#  'Audio Physic sound system with Bluetooth and aux',
#  'Oven] [Outdoor furniture',
#  'Free dryer \\u2013 In unit',
#  'Outdoor shower',
#  'Shea Logix body soap',
#  'Private gym',
#  '42\\ TV',
#  'Bodywash body soap',
#  'Dishes and silverware] [Dryer \\u2013 In building',
#  'Double oven',
#  'Self check-in] [Essentials',
#  'Free washer \\u2013 In building',
#  'Netflix] [Fire extinguisher',
#  'Accessible-height bed',
#  'standard cable] [Hot water kettle',
#  'Denon Home Theater Receiver with Boston Acoustics speakers + Subwoofer sound system with aux',
#  'Beach essentials',
#  'Wifi \\u2013 224 Mbps',
#  'Children\\u2019s dinnerware',
#  'Self check-in] [Cleaning products',
#  'GE Cafe stainless steel oven',
#  'neutrogena body soap',
#  '42\\ HDTV with Amazon Prime Video',
#  'Gaggenau stainless steel gas stove',
#  'Shared gym in building',
#  'Shared garden or backyard] [Hot water kettle',
#  'Oven] [Long term stays allowed',
#  'Dial body wash  body soap',
#  'Host greets you] [Microwave',
#  'Wolf refrigerator',
#  'IKEA gas stove',
#  '56\\ HDTV with Apple TV',
#  'dunno refrigerator',
#  'Oven] [Microwave',
#  'Projector and screen',
#  'Harmon Kardon sub',
#  'Jason body soap',
#  'Head and Shoulders (usually!)  conditioner',
#  'Shared outdoor heated pool',
#  'Coffee maker] [Hot water kettle',
#  'Boom box sound system with Bluetooth and aux',
#  'Hot tub] [Microwave',
#  'and closet',
#  'Smoke detector',
#  'Viking stainless steel gas stove',
#  'High chair] [Gas stove',
#  'Iron] [Long term stays allowed] [Free street parking',
#  'TV] [Dedicated workspace: office chair and desk',
#  'Various body soap',
#  'Jason org\\u00e1nica  body soap',
#  'Single level home] [Dedicated workspace',
#  'Wifi \\u2013 100 Mbps',
#  'Honest Company and Pantene pro v conditioner',
#  'Pro series 6 burner gas stove',
#  'Sonos interfaced-system sound system',
#  'Clothing storage: wardrobe and closet',
#  '42\\ HDTV with Apple TV',
#  'kiehls shampoo',
#  'Wifi \\u2013 25 Mbps',
#  'Mini fridge] [Outdoor dining area',
#  'Coffee maker] [Outdoor dining area',
#  'Kitchen Aid stainless steel gas stove',
#  'TV with standard cable] [Paid parking garage off premises',
#  '46\\ TV',
#  'Oven] [Free street parking',
#  'Wifi \\u2013 47 Mbps',
#  'Aesop shampoo',
#  'Heating] [Cleaning products',
#  'Sony Bluetooth sound system',
#  'Walk in closet',
#  'Iron] [50\\ HDTV with Netflix',
#  'Suave body soap',
#  'Steam room',
#  'Fixed grab bars for shower',
#  'Coffee maker] [Free parking garage on premises',
#  'samsung refrigerator',
#  'Dedicated workspace: desk] [Outdoor furniture',
#  'Rice maker',
#  'Iron] [Single level home',
#  'GE stainless steel induction stove',
#  'Paid parking off premises] [Portable heater',
#  'Bluetooth sound system] [BBQ grill',
#  'Game console: Nintendo Wii U',
#  'Self check-in] [Free street parking',
#  'TV with standard cable] [Free street parking',
#  'Babysitter recommendations',
#  "Women's caress Men's Old spice body soap",
#  'Shampoo] [Dedicated workspace',
#  'Dove shampoo',
#  'Iron] [Outdoor furniture',
#  'Ceiling fan',
#  'Wolf gas stove',
#  'Bath & Body Works body soap',
#  'Keypad] [Cleaning products',
#  'Clothing storage: wardrobe and closet] [Hot water kettle',
#  'Cusimax portable electric stove',
#  'Iron] [Outdoor dining area',
#  'Free residential garage on premises',
#  'Shikai conditioner',
#  'Wifi \\u2013 80 Mbps',
#  'single use tube on arrival conditioner',
#  '32\\ HDTV with Netflix',
#  'Jam box  sound system with Bluetooth and aux',
#  'Fixed grab bars for toilet',
#  'Oven] [Dedicated workspace',
#  'Convection oven',
#  'Cuisinart stainless steel electric stove',
#  'Dryer',
#  'Geneva sound system with Bluetooth and aux',
#  "Dove & Kiehl's  body soap",
#  'Onkyo sound system',
#  'Silkience Hydrating Shampoo conditioner',
#  'Game console: Xbox 360',
#  'TV] [Shared fenced garden or backyard',
#  '52\\ HDTV with Roku',
#  'Wifi \\u2013 35 Mbps',
#  'Iron] [Marshall',
#  'Dr Bronners body soap',
#  '48\\ TV with standard cable',
#  'Olay Body Wash body soap',
#  'Whole Foods 365 shampoo',
#  'Carbon monoxide alarm] [Long term stays allowed',
#  'Luggage dropoff allowed] [Essentials',
#  '37\\ HDTV with standard cable',
#  "Rudy's Conditioner (Ace Hotel brand) conditioner",
#  'Sonos 2 speakers Bluetooth sound system',
#  "Rudy's \\u00b7\\u00a0Ace Hotel shampoo",
#  'Neutrogena  body soap',
#  'Laptop friendly workspace',
#  'Kitchenette',
#  '50\\ HDTV with Apple TV',
#  'Standard body soap',
#  'Self check-in] [Microwave',
#  'TV with standard cable] [Board games',
#  'Paid street parking off premises',
#  'Coffee maker] [Shared fenced garden or backyard',
#  '28\\ HDTV with Amazon Prime Video',
#  'Cuisinart portable countertop burner (one) stainless steel stove',
#  'Ski-in/Ski-out',
#  'High chair] [Essentials',
#  'Shaikai shampoo',
#  'Smoke alarm] [Essentials',
#  'Free parking on premises] [Cleaning products',
#  'HDTV with ] [Breakfast',
#  'Wifi \\u2013 423 Mbps',
#  'TV] [Fire extinguisher',
#  'Wifi \\u2013 70 Mbps',
#  '365 Everyday body soap',
#  'Suave conditioner] [Free street parking',
#  'Off-Brand gas stove',
#  'Conduction electric stove',
#  '84\\ HDTV with standard cable',
#  'Coffee maker] [Dedicated workspace',
#  'Essentials  shampoo',
#  '43\\ HDTV',
#  'Paid parking lot on premises',
#  '55\\ TV with Netflix',
#  'Keypad] [Dryer',
#  'Massage table',
#  'Bertazzoni stainless steel oven',
#  'Thermador oven',
#  'Fragrance free from Whole Foods shampoo',
#  'Clothing storage] [Gym',
#  'Wifi \\u2013 780 Mbps',
#  'Sound system with aux',
#  'Oxy shampoo',
#  'premium cable] [Essentials',
#  'Ceiling fan] [Breakfast',
#  'Heat lamps',
#  'Apple sound system',
#  '55\\ HDTV with premium cable',
#  'Sonos sound system with Bluetooth and aux',
#  'Bosch oven',
#  'Cuisinart Countertop Double Burner stainless steel electric stove',
#  'TV with standard cable] [Hot water kettle',
#  'Some pots and pans are kept in the oven oven',
#  'Iron] [Microwave',
#  'Everyone 4 Everybody body soap',
#  'Kitchenaid refrigerator',
#  'Stainless steel electric stove',
#  'Wolf stainless steel gas stove',
#  'Aveda conditioner',
#  'Formal dining area',
#  'Wifi \\u2013 600 Mbps',
#  '2-5 years old',
#  'Luggage dropoff allowed] [Free street parking',
#  'Miscellaneous body soap',
#  'TV] [Dedicated workspace: table',
#  '32\\ TV',
#  'Sonos  Bluetooth sound system',
#  'Stove] [Breakfast',
#  'Paid dryer \\u2013 In unit',
#  'Smoke alarm] [Free street parking',
#  'Carbon monoxide detector',
#  'Well-lit path to entrance',
#  'Enriched with Shea Butter',
#  'Dishes and silverware] [BBQ grill',
#  'Kenmoore refrigerator',
#  'Iron] [Full kitchen',
#  'Fragrance free from Whole foods conditioner',
#  'Gym] [BBQ grill',
#  'Security cameras] [BBQ grill',
#  'BlueStar stainless steel gas stove',
#  '43\\ TV with Netflix',
#  'Wide clearance to shower',
#  'Kiehls conditioner',
#  "L'Occitane body soap",
#  'Herbal Essences conditioner',
#  'Hot tub',
#  'and wardrobe',
#  'Oven] [Single level home',
#  'Sonos around the whole home including the yard sound system',
#  'TV] [Sonos Bluetooth sound system',
#  'Electric stove] [Hot water kettle',
#  'Smart lock',
#  'Wifi \\u2013 198 Mbps',
#  'Host greets you] [Portable heater',
#  'Shower gel] [Breakfast',
#  'Shared pool] [Fire extinguisher',
#  'Coffee maker] [Air conditioning',
#  'Amazon Alexa Bluetooth sound system',
#  'Essentials  conditioner',
#  'Free carport on premises',
#  'Wifi \\u2013 415 Mbps',
#  'Electric profiling bed',
#  'Private hot tub',
#  'Wifi \\u2013 1200 Mbps',
#  'Washer',
#  "Dr. Bronner's Pure Castille body soap",
#  'Hot tub] [Outdoor furniture',
#  'Record player',
#  'Private entrance',
#  'Paid parking on premises',
#  'TV with standard cable] [Fire extinguisher',
#  'New LG Gas Range with 5 stovetop burners stainless steel stove',
#  'Clothing storage: closet and walk-in closet',
#  "C'est La Vie Hydrating Conditioner+Argan oil conditioner",
#  'Private hot tub] [BBQ grill',
#  '365 shampoo',
#  'Iron] [Dedicated workspace',
#  'Surround Sound sound system',
#  'Hammock',
#  'sonos sound system',
#  'Heating',
#  'and dresser',
#  'Mini fridge] [Free street parking',
#  'TV] [Paid parking garage off premises',
#  'Game console: Nintendo Switch and PS5',
#  'Ginger Lily Farms body soap',
#  'Dishes and silverware] [Cleaning products',
#  'Hot tub] [Hot water kettle',
#  'Electric stove] [Microwave',
#  'Radiant heating',
#  'High chair] [Gym',
#  'Dedicated workspace: desk] [Fire extinguisher',
#  'Private hot tub] [Dedicated workspace',
#  'Bertazoni stainless steel oven',
#  'Viking gas stove',
#  'Coffee maker] [Hot water',
#  'Ceiling fan] [Hot water kettle',
#  'Fragrance free from Whole Foods body soap',
#  'toaster oven stainless steel oven',
#  'Children\\u2019s books and toys for ages 5-10 years old',
#  'Smoking allowed',
#  'Wifi \\u2013 611 Mbps',
#  'Host greets you] [BBQ grill',
#  'Panthene conditioner',
#  'Oven] [Gas stove',
#  'TV with standard cable] [BBQ grill',
#  'Oven] [Dryer',
#  'Lock on bedroom door] [Dedicated workspace',
#  'Wifi \\u2013 85 Mbps',
#  'Cleaning before checkout',
#  'Clothing storage] [Shared fenced garden or backyard',
#  'Gaggenau cooktop gas stove] [Fire extinguisher',
#  'Paid parking off premises] [Hot water kettle',
#  'and not meant to be shared. refrigerator',
#  'Building staff',
#  'Single level home] [Hot water',
#  'HDTV with premium cable',
#  'Frigidaire stainless steel oven',
#  'Bath towel',
#  'Wifi \\u2013 900 Mbps',
#  'TRESemm\\u00e9 shampoo',
#  'Oven] [Fire extinguisher',
#  '55\\ HDTV with Chromecast',
#  'Host greets you] [Gas fireplace',
#  'Free parking on premises] [Hot water kettle',
#  'Apple TV',
#  'Stove] [Essentials',
#  'Exercise equipment',
#  'Central air conditioning',
#  "Kiehl's shampoo",
#  'Off-Brand oven] [Fire extinguisher',
#  '48\\ HDTV with Netflix',
#  '47\\ HDTV with Netflix',
#  'moisturizing body soap',
#  'Lock on bedroom door] [Long term stays allowed',
#  'steam + convection + gas stainless steel oven',
#  'Disabled parking spot',
#  'natural body soap',
#  'Paya Organics body soap',
#  'Sub-Zero refrigerator',
#  'Patio or balcony',
#  'premium cable',
#  '50\\ HDTV',
#  'Dove fragrance free body soap',
#  'Kenmore stainless steel gas stove',
#  '4 burners and double oven electronic control stainless steel gas stove] [Free street parking',
#  'table',
#  'Free parking on premises \\u2013 2 spaces',
#  'Pantene/Dove/Costco conditioner',
#  'Coffee maker] [Elevator',
#  'TRESemm\\u00e9 conditioner',
#  'Elizabeth W products body soap',
#  'Host greets you] [Paid parking garage off premises',
#  'Wolf stainless steel oven',
#  'Amazon Bluetooth sound system',
#  'Aussie shampoo',
#  'Kenmore refrigerator] [Paid street parking off premises',
#  'Whirlpool  refrigerator',
#  'Nuskin body soap] [Essentials',
#  'Free parking on premises] [Breakfast',
#  'Standing valet',
#  'Frigidaire refrigerator',
#  'Oven] [Hot water kettle',
#  'TV] [Carbon monoxide alarm',
#  'GE Cafe stainless steel gas stove',
#  'Coffee maker] [Smoke alarm',
#  'Game console: Nintendo Switch',
#  'Internet',
#  'Pert shampoo',
#  "Suave Men's and Dove body soap",
#  'Heating] [Single level home',
#  'Natural  body soap',
#  'New LG Gas range with Air Fry stainless steel oven',
#  'Electric stove] [Fire extinguisher',
#  'Tressemme conditioner',
#  'Security cameras on property] [Fire extinguisher',
#  'Suave Apple scented shampoo',
#  'Whole Foods 365 Fragrance Free body soap',
#  'Bluetooth sound system] [Fire extinguisher',
#  'Paid parking garage on premises',
#  'Lock on bedroom door] [Essentials',
#  'linens',
#  'Hot tub] [BBQ grill',
#  'Microwave',
#  'TV with Chromecast',
#  'Lock on bedroom door] [Hot water kettle',
#  'Jawbone sound system with Bluetooth and aux',
#  'Building staff] [Hot water kettle',
#  'perlick refrigerator',
#  'Dining area',
#  'Kitchenette] [Essentials',
#  'Wifi] [Hot water kettle',
#  'Alba Botanica shampoo',
#  'Coffee maker] [Outdoor furniture',
#  'Keypad] [Hot water kettle',
#  'Wifi \\u2013 526 Mbps',
#  'Apple Bluetooth sound system',
#  'Auromere ayurvedic soap body soap',
#  'GE stove',
#  'Dedicated workspace] [Hot water kettle',
#  'Wide entrance for guests',
#  'Thermador dual oven',
#  'Technics receiver/amp w/ Paradigm speakers sound system with aux',
#  'Samsung stainless steel gas stove',
#  'brand new whirlpool refrigerator',
#  'Waterfront',
#  'Mini fridge] [Hot water kettle',
#  'Free washer',
#  'Paid parking garage on premises \\u2013 4 spaces',
#  '55\\ HDTV with Netflix',
#  'Generic body soap',
#  'Dedicated workspace: desk] [Hot water kettle',
#  'Paya Organics shampoo',
#  'Wifi] [Fire extinguisher',
#  'Aveno body soap',
#  'Bathrobes',
#  '50\\ TV with Netflix',
#  'Clothing storage] [Essentials',
#  'Gas stove',
#  'Self check-in] [TV with Netflix',
#  'HDTV with Amazon Prime Video',
#  'Heating] [Microwave',
#  'Alexa voice-controlled sound system with speakers in every room & Prime music Bluetooth sound system',
#  'Kenmore electric range. oven',
#  'Private entrance] [Breakfast',
#  'Eco Friendly conditioner',
#  'Apple HomePod',
#  'Fire extinguisher',
#  'TV] [Hot water kettle',
#  'Bumble & Bumble conditioner',
#  'Wifi \\u2013 77 Mbps',
#  'Private hot tub] [Fire extinguisher',
#  'Private in-unit mini-fridge. refrigerator',
#  'Amazon Prime Video',
#  'Gas oven oven',
#  'Wifi \\u2013 404 Mbps',
#  'Ikea shampoo',
#  'office chair',
#  'Stove] [BBQ grill',
#  'JENN-AIR refrigerator',
#  '365 conditioner',
#  'Viking refrigerator',
#  'Shampoo] [Hot water kettle',
#  'Yamaha 7.2 sound system',
#  'Clothing storage] [Breakfast',
#  'Heating] [Frigidaire gas stove',
#  'Touchless faucets',
#  'U-Line with Freezer refrigerator',
#  '46\\ HDTV with Netflix',
#  'Kenmore refrigerator] [Dryer',
#  'Coffee maker] [Long term stays allowed',
#  'JBL Bluetooth sound system',
#  'Smoke alarm] [Carbon monoxide alarm',
#  'World Amenities shampoo',
#  'Crib] [Fire extinguisher',
#  '55\\ HDTV with Roku',
#  'Game console: Xbox Series X',
#  'Paid valet parking on premises',
#  'Wifi \\u2013 133 Mbps',
#  'Pillow-top mattress',
#  'Frangrance free from Whole Foods body soap] [Free street parking',
#  "Dr. Bronner's body soap",
#  'Stereo soundbar sound system with Bluetooth and aux',
#  'Self check-in] [Fire extinguisher',
#  'Whirlpool oven',
#  'Dedicated workspace: desk] [Dedicated workspace: office chair and desk',
#  'Long term stays allowed] [Free street parking',
#  'Clothing storage] [Hot water kettle',
#  '65\\ HDTV with Amazon Prime Video',
#  'Stove] [Microwave',
#  'Free parking on premises',
#  'Indoor fireplace',
#  'Free parking garage on premises',
#  'Heating] [BBQ grill',
#  'HBO GO',
#  'Single level home] [50\\ HDTV with Amazon Prime Video',
#  'Hangers',
#  'and desk',
#  'Vicking refrigerator',
#  'Shared sauna',
#  'AVEDA Shampure conditioner] [Hot water kettle',
#  'Ironing board',
#  'Whirlpool stainless steel oven',
#  'Crib] [Outdoor dining area',
#  '54\\ HDTV with Roku',
#  'Mini fridge] [Fire extinguisher',
#  'TV] [Gas stove',
#  'Free dryer \\u2013 In building',
#  'Iron] [Fire extinguisher',
#  'Wifi \\u2013 366 Mbps',
#  'Tea Tree shampoo',
#  'Wifi] [Microwave',
#  'and walk-in closet',
#  'High chair] [BBQ grill',
#  'Clothing storage: wardrobe and dresser',
#  'Washer \\u2013\\u00a0In unit',
#  'Crib] [Microwave',
#  '32\\ TV with',
#  'GE stainless steel oven',
#  'Everyone for every body soap shampoo and body wash shampoo',
#  'Free parking on premises \\u2013 1 space',
#  'with freezer refrigerator',
#  'Bose sound system with aux',
#  'bosch refrigerator',
#  'NXT and Yamaha in wall theater system sound system',
#  'Wifi \\u2013 90 Mbps',
#  'Iron] [Paid street parking off premises',
#  'Refrigerator',
#  'Roll-in shower',
#  'Barbecue utensils',
#  'Toilet paper',
#  'Paid parking off premises] [BBQ grill',
#  'High chair] [Long term stays allowed] [Long term stays allowed] [Long term stays allowed] [Long term stays allowed] [Long term stays allowed] [Long term stays allowed] [Long term stays allowed] [Long term stays allowed] [Long term stays allowed] [Long term stays allowed] [Essentials',
#  'Dedicated workspace: table and desk',
#  'Private hot tub] [Hot water',
#  'TV with standard cable] [Portable heater',
#  'standard cable',
#  'Coffee maker] [BBQ grill',
#  'BlueStar Six (6) Burner Range stainless steel oven',
#  'Wifi \\u2013 439 Mbps',
#  'TRESemme shampoo',
#  '2 Burner Glass Stovetop electric stove',
#  'Stainless steel induction stove',
#  'Heating] [Dedicated workspace: office chair and desk',
#  'Suave conditioner] [Fire extinguisher',
#  'Luggage dropoff allowed] [Hot water kettle',
#  'Drying rack for clothing',
#  'single use tube on arrival shampoo',
#  '55\\ TV with Amazon Prime Video',
#  'Avanti stainless steel oven',
#  'Costco body soap',
#  'Private sauna',
#  'PURE by Gloss shampoo',
#  '3 Minute Miracle Moist conditioner',
#  'TV with',
#  'Ge refrigerator',
#  'Electric stove] [Essentials',
#  'HDTV with HBO Max',
#  'Clothing storage] [Long term stays allowed',
#  'TV with standard cable] [Dedicated workspace: office chair and desk',
#  'AND CONDITIONER shampoo',
#  'Full kitchen',
#  'Wifi \\u2013 75 Mbps',
#  'Mini-fridge refrigerator',
#  'Iron] [Board games',
#  'Shea Logix conditioner',
#  'Wolf stainless steel stove',
#  '42\\ HDTV with HBO Max',
#  'Bertazoni stainless steel gas stove',
#  'Pets allowed',
#  'Alba shampoo',
#  'Trader Joes conditioner',
#  'ASCO gas oven oven',
#  'Jetted tub',
#  'walk-in closet',
#  '55\\ HDTV with Apple TV',
#  'variety body soap',
#  'Bath & Body Works shampoo',
#  'High chair] [Free street parking',
#  'Keypad] [BBQ grill',
#  'Smoke alarm] [Hot water kettle',
#  'Freezer] [BBQ grill',
#  'AESOP body soap',
#  'Wifi \\u2013 248 Mbps] [Cleaning products',
#  '43\\ HDTV with Roku',
#  'Oven',
#  'Method and E&O body soap',
#  'TV',
#  'Cleaning before checkout] [Microwave',
#  'Dedicated workspace: monitor and desk',
#  'Paid parking garage on premises \\u2013 1 space',
#  'Wifi \\u2013 800 Mbps',
#  'Concierge',
#  'Everyone for every body soap shampoo and body wash body soap',
#  'Polk built-in speakers via Airplay sound system',
#  'Usually Pantene conditioner',
#  'Beachfront',
#  'Stand alone rain shower',
#  'Chromecast',
#  'Viking stainless steel stove',
#  'No stairs or steps to enter',
#  'Dedicated workspace: monitor and table',
#  'Pocket wifi',
#  'Hair dryer',
#  'Host greets you] [Breakfast',
#  'Various  conditioner',
#  'Vizio sound system with Bluetooth and aux',
#  'Gym] [Fire extinguisher',
#  'Blue Star - Full Sheet Pan stainless steel oven',
#  'Smoke alarm] [Microwave',
#  'Dedicated workspace: desk] [Carbon monoxide alarm',
#  'Dishwasher',
#  'Crib',
#  'Host greets you] [Hot water kettle',
#  'Self check-in',
#  'Wifi] [Essentials',
#  'Carbon monoxide alarm] [Microwave',
#  'Keypad] [Board games',
#  'Toaster Oven oven',
#  'Shikai  body soap',
#  'Wifi \\u2013 150 Mbps',
#  'Fridigaire refrigerator',
#  'sonos Bluetooth sound system',
#  'Dedicated workspace: desk] [Microwave',
#  'Keypad',
#  'Maytag refrigerator',
#  'Mini fridge] [Shared fenced garden or backyard',
#  'Dove (sensitive skin) body soap',
#  'Kitchen Aid refrigerator',
#  'Single level home] [Backyard',
#  'Denon',
#  'Bausch stainless steel electric stove',
#  'Ice Machine',
#  'HomePods Bluetooth sound system',
#  'Whole Foods 365 Fragrance Free shampoo',
#  'Cleaning products',
#  'Clothing storage] [Fire extinguisher',
#  'Samsung stainless steel oven',
#  'Iron] [Long term stays allowed',
#  'tea tree shampoo',
#  'medium size refrigerator refrigerator',
#  'Aveeno conditioner',
#  'dunno oven',
#  'Private hot tub] [Microwave',
#  'Pantene conditioner',
#  'Bedroom comforts',
#  'Hot tub] [Fire extinguisher',
#  'Stair gates',
#  'Children‚Äôs dinnerware',
#  'Magic Chef refrigerator',
#  'Bar soap or body wash  body soap',
#  'Suave conditioner] [Microwave',
#  'Trader Joes body soap',
#  'Private hot tub] [Free street parking',
#  'Iron] [Free street parking',
#  'Wifi \\u2013 117 Mbps',
#  'Single level home] [Outdoor dining area',
#  'Baking sheet',
#  'TRESemme conditioner',
#  'Viking 36\\u201d stainless steel oven',
#  'Niles',
#  '52\\ HDTV with Amazon Prime Video',
#  'Free residential garage on premises \\u2013 2 spaces',
#  'Elevator] [Carbon monoxide alarm',
#  'various body soap',
#  '65\\ HDTV with premium cable',
#  'Paid parking off premises] [Carbon monoxide alarm',
#  'Conditioner] [Free street parking',
#  'Wifi \\u2013 329 Mbps',
#  'Stove] [Hot water kettle',
#  'Mini fridge',
#  'Piano',
#  'Wide entryway',
#  '45\\ HDTV with Amazon Prime Video',
#  'Bosch LED glass top stove',
#  'Herbal Essences shampoo',
#  'Wifi \\u2013 144 Mbps',
#  'E&O body soap',
#  'Kayak',
#  'Coffee maker] [Microwave',
#  'Costco conditioner',
#  'Coffee maker] [Carbon monoxide alarm',
#  'Natural gas barbeque',
#  'Google Home Bluetooth sound system',
#  'Coffee maker] [Cleaning products',
#  'bose sound system with Bluetooth and aux',
#  'lavender shampoo and body wash body soap',
#  'Miele stainless steel gas stove',
#  'Viking oven',
#  'TV with standard cable] [Long term stays allowed',
#  'Iron',
#  'and office chair] [Hot water kettle',
#  'Toaster Oven stainless steel oven',
#  'Kitchenette] [Free street parking',
#  'Clothing storage',
#  'Electric stove] [Cleaning products',
#  'Wifi \\u2013 413 Mbps',
#  'Avanti stainless steel gas stove',
#  'Pantene shampoo',
#  ...}

# %%
# lets combine comman phrases like Balcony = Patio or balcony

# %%
# Produces a list of amenity features where one category (true or false) contains fewer than 10% of listings
fewer_amenities = []
for col in df.iloc[:,41:].columns:
    if df[col].sum() < len(df)/10:
        fewer_amenities.append(col)
print(fewer_amenities)

# Dropping fewer amenity features
df.drop(fewer_amenities, axis=1, inplace=True)

# Dropping the original amenity feature
df.drop('amenities', axis=1, inplace=True)
# Out:
# []

# %%
# Replacing nulls with zeros for new columns
replace_nulls = df.iloc[:,39:].columns
df[replace_nulls] = df[replace_nulls].fillna(0)

# %%
# Produces a list of amenity features where one category (true or false) contains fewer than 10% of listings
fewer_amenities = []
for col in df.iloc[:,41:].columns:
    if df[col].sum() < len(df)/10:
        fewer_amenities.append(col)
print(fewer_amenities)
# Out:
# []

# %%
# Dropping fewer amenity features
df.drop(fewer_amenities, axis=1, inplace=True)

# %%
# # Dropping calender_update features
df.drop('calendar_updated', axis=1, inplace=True)

# %%
# print null values in first_review and revies_score_rating columns
print(f"Null values in 'first_review': {round(100*df.first_review.isna().sum()/len(df),1)}%")
print(f"Null values in 'review_scores_rating': {round(100*df.review_scores_rating .isna().sum()/len(df),1)}%")
# Out:
# Null values in 'first_review': 19.0%
# Null values in 'review_scores_rating': 19.2%

# %%
# Converting to datetime
df.first_review = pd.to_datetime(df.first_review) 

# Number of days between the first review and the date the data was scraped
df['time_since_first_review'] = (datetime(2019, 6, 2) - df.first_review).astype('timedelta64[D]')

# %%
# Distribution of the number of days since first review
df.time_since_first_review.hist(figsize=(10,6), bins=20);

# %%
# Takes in a column name, bin cut points and labels, replaces the original column with a  binned version, and replaces nulls (with 'unknown' if unspecified).
    
def bin_column(col, bins, labels, na_label='unknown'):
    df[col] = pd.cut(df[col], bins=bins, labels=labels, include_lowest=True)
    df[col] = df[col].astype('str')
    df[col].fillna(na_label, inplace=True)

# %%
# Binning time (since first review)
bin_column('time_since_first_review',
           bins=[0, 180, 365, 730, 1460, max(df.time_since_first_review)],
           labels=['0-6 months',
                   '6-12 months',
                   '1-2 years',
                   '2-3 years',
                   '4+ years'],
           na_label='no reviews')

# %%
# Repeating process for last review and converting to datetime
 
df.last_review = pd.to_datetime(df.last_review) 

# Calculating the number of days between the last review and the date the data was scraped
df['time_since_last_review'] = (datetime(2019, 6, 2) - df.last_review).astype('timedelta64[D]')

# %%
# Distribution of the number of days since last review
df.time_since_last_review.hist(figsize=(10,6), bins=30);

# %%
# Binning time since last review
bin_column('time_since_last_review',
           bins=[0, 60, 180, 365, 1460, max(df.time_since_last_review)],
           labels=['0-2 weeks',
                   '2-8 weeks',
                   '2-6 months',
                   '6-12 months',
                   '1+ year'],
           na_label='no reviews')

# %%
# Drop last_review as looks like not needed
df.drop('last_review', axis=1, inplace=True)

# %%
# review the distributions of the review ratings columns
variables_to_plot = list(df.columns[df.columns.str.startswith("review_scores") == True])
fig = plt.figure(figsize=(12,8))
for i, var_name in enumerate(variables_to_plot):
    ax = fig.add_subplot(3,3,i+1)
    df[var_name].hist(bins=10,ax=ax)
    ax.set_title(var_name)
fig.tight_layout()
plt.show()

# %%
# reviews_per_month and number_of_reviews are common and related so dropping this will not affect analysis
df.drop(['number_of_reviews_ltm', 'reviews_per_month'], axis=1, inplace=True)

# %%
df.head()
df.dtypes
# Out:
# host_since                 datetime64[ns]
# host_response_time                 object
#                                 ...
# time_since_first_review            object
# time_since_last_review             object
# Length: 39, dtype: object

# %%
# now save cleaned data set
listings_cleaned = df.to_csv('./resources/listings_cleaned2.csv', index=id, header=True)
