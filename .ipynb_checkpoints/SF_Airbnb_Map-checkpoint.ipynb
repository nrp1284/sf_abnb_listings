# %%
import pandas as pd
import gmaps
import requests

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/dr/j38bc0l141752t2khgdg1jvc0000gn/T/ipykernel_4900/2196567407.py in <module>
#       4
#       5 # Import API key
# ----> 6 from config import g_key
#       7
#       8 # Configure gmaps
#
# ModuleNotFoundError: No module named 'config'

# %%
file = "Resources/listings_cleaned2.csv"

# %%
region_df = pd.read_csv(file)
region_df.head()

# %%
region_df.dtypes

# %%
# Filter hosts and
clean_df = region_df.loc[(region_df["host_response_rate"] == '100%') & 
                        (region_df['host_is_superhost'] == 1) &
                        (region_df['host_identity_verified'] == 1) &
                        (region_df['instant_bookable'] == 1) & 
                        # review ratings.
                        (region_df['review_scores_rating'] >= 80) & 
                        (region_df['review_scores_accuracy'] >= 7) & 
                        (region_df['review_scores_cleanliness'] >= 7) & 
                        (region_df['review_scores_checkin'] >= 7) & 
                        (region_df['review_scores_communication'] >= 7) & 
                        (region_df['review_scores_location'] >= 7) & 
                        (region_df['review_scores_value'] >= 7) &
                        # recent calendar updates.
                        (region_df['calendar_updated'] != '17 months ago') &
                        (region_df['calendar_updated'] != '14 months ago') &
                        (region_df['calendar_updated'] != '12 months ago')]
clean_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dr/j38bc0l141752t2khgdg1jvc0000gn/T/ipykernel_4900/3587128437.py in <module>
#       1 # Filter hosts and
# ----> 2 clean_df = region_df.loc[(region_df["host_response_rate"] == '100%') &
#       3                         (region_df['host_is_superhost'] == 1) &
#       4                         (region_df['host_identity_verified'] == 1) &
#       5                         (region_df['instant_bookable'] == 1) &
#
# NameError: name 'region_df' is not defined

# %%
clean_df.calendar_updated.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/dr/j38bc0l141752t2khgdg1jvc0000gn/T/ipykernel_4900/62247859.py in <module>
# ----> 1 clean_df.calendar_updated.value_counts()
#
# NameError: name 'clean_df' is not defined

# %%
# Ask the customer to add a minimum and maximum price value.
min_price = float(input("What is the minimum price you would like for your hotel? "))
max_price = float(input("What is the maximum price you would like for your hotel? "))
# Out:
# What is the minimum price you would like for your hotel? 50
# What is the maximum price you would like for your hotel? 100

# %%
# Filter the dataset to find the hotels that fit the criteria.
preferred_df = clean_df.loc[(clean_df["price"] <= max_price) & (clean_df["price"] >= min_price)]
preferred_df
# Out:
#               id host_since host_response_time host_response_rate  \
# 11       12522.0    5/22/09     within an hour               100%
# 18       23611.0    5/25/09     within an hour               100%
# 135     208727.0    4/19/11     within an hour               100%
# 157     256176.0    8/16/11     within an hour               100%
# 247     474107.0     5/8/12     within an hour               100%
# ...          ...        ...                ...                ...
# 4713  31206489.0    9/11/14     within an hour               100%
# 4762  31595144.0     4/3/12     within an hour               100%
# 4835  32210241.0    1/29/12     within an hour               100%
# 4894  32617586.0     3/4/13     within an hour               100%
# 4918  32724526.0    9/20/14     within an hour               100%
#
#       host_is_superhost  host_listings_count  host_total_listings_count  \
# 11                  1.0                  1.0                        1.0
# 18                  1.0                  3.0                        3.0
# 135                 1.0                  8.0                        8.0
# 157                 1.0                  1.0                        1.0
# 247                 1.0                  1.0                        1.0
# ...                 ...                  ...                        ...
# 4713                1.0                  3.0                        3.0
# 4762                1.0                  4.0                        4.0
# 4835                1.0                  4.0                        4.0
# 4894                1.0                  6.0                        6.0
# 4918                1.0                  1.0                        1.0
#
#       host_identity_verified neighbourhood_cleansed  zipcode  ...  \
# 11                       1.0    Castro/Upper Market  94110.0  ...
# 18                       1.0         Bernal Heights  94110.0  ...
# 135                      1.0         Outer Richmond  94121.0  ...
# 157                      1.0         Inner Richmond  94118.0  ...
# 247                      1.0              Excelsior  94112.0  ...
# ...                      ...                    ...      ...  ...
# 4713                     1.0             Noe Valley  94114.0  ...
# 4762                     1.0         Bernal Heights  94110.0  ...
# 4835                     1.0        Pacific Heights  94115.0  ...
# 4894                     1.0                Mission  94110.0  ...
# 4918                     1.0              Glen Park  94131.0  ...
#
#       instant_bookable  calculated_host_listings_count  \
# 11                 1.0                             1.0
# 18                 1.0                             2.0
# 135                1.0                             2.0
# 157                1.0                             1.0
# 247                1.0                             1.0
# ...                ...                             ...
# 4713               1.0                             3.0
# 4762               1.0                             4.0
# 4835               1.0                             3.0
# 4894               1.0                             5.0
# 4918               1.0                             1.0
#
#      calculated_host_listings_count_entire_homes  \
# 11                                           0.0
# 18                                           1.0
# 135                                          0.0
# 157                                          0.0
# 247                                          0.0
# ...                                          ...
# 4713                                         0.0
# 4762                                         1.0
# 4835                                         1.0
# 4894                                         0.0
# 4918                                         1.0
#
#      calculated_host_listings_count_private_rooms  \
# 11                                            1.0
# 18                                            1.0
# 135                                           2.0
# 157                                           1.0
# 247                                           1.0
# ...                                           ...
# 4713                                          3.0
# 4762                                          3.0
# 4835                                          2.0
# 4894                                          5.0
# 4918                                          0.0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 11                                            0.0               3.48
# 18                                            0.0               2.17
# 135                                           0.0               0.33
# 157                                           0.0               3.12
# 247                                           0.0               2.52
# ...                                           ...                ...
# 4713                                          0.0               6.27
# 4762                                          0.0               5.82
# 4835                                          0.0               2.06
# 4894                                          0.0               1.38
# 4918                                          0.0               5.29
#
#       host_days_active  time_since_first_review  time_since_last_review  \
# 11              3663.0                 4+ years                    18.0
# 18              3660.0                 4+ years                     9.0
# 135             2966.0                 4+ years                   265.0
# 157             2847.0                 4+ years                     4.0
# 247             2581.0                1-2 years                    11.0
# ...                ...                      ...                     ...
# 4713            1725.0               0-6 months                     4.0
# 4762            2616.0               0-6 months                     1.0
# 4835            2681.0               0-6 months                    20.0
# 4894            2281.0               0-6 months                    28.0
# 4918            1716.0               0-6 months                    10.0
#
#                                 listing_url
# 11       https://www.airbnb.com/rooms/12522
# 18       https://www.airbnb.com/rooms/23611
# 135     https://www.airbnb.com/rooms/208727
# 157     https://www.airbnb.com/rooms/256176
# 247     https://www.airbnb.com/rooms/474107
# ...                                     ...
# 4713  https://www.airbnb.com/rooms/28079442
# 4762  https://www.airbnb.com/rooms/28407357
# 4835  https://www.airbnb.com/rooms/28920042
# 4894  https://www.airbnb.com/rooms/29385707
# 4918  https://www.airbnb.com/rooms/29587356
#
# [110 rows x 46 columns]

# %%
# Create a descirption box.
info_box_template = """
<dl>
<dt>ID</dt><dd>{id}</dd>
<dt>Neighbourhood</dt><dd>{neighbourhood_cleansed}</dd>
<dt>Price</dt><dd>{price}</dd>
<dt>Rating</dt><dd>{review_scores_rating}</dd>
</dl>
"""

# Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in preferred_df.iterrows()]

# Get the latitude and longitude from each row and store in a new DataFrame.
locations = preferred_df[["latitude", "longitude"]]

# %%
# Assign the figure variable.
fig = gmaps.figure(center=(37.77, -122.4), zoom_level=11.8)

# Add a marker_layer.
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# Display.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
