# %%
# %matplotlib inline

# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import hvplot.pandas
from pathlib import Path
import plotly.express as px

# %%
file_path = "./resources/sf_airbnb_listings.csv"
ab_df = pd.read_csv(file_path,index_col=0)
ab_df.head(10)
# Out:
#                               listing_url     scrape_id last_scraped  \
# id
# 958      https://www.airbnb.com/rooms/958  2.020000e+13     6/2/2019
# 7918    https://www.airbnb.com/rooms/7918  2.020000e+13     6/2/2019
# 8142    https://www.airbnb.com/rooms/8142  2.020000e+13     6/2/2019
# 8339    https://www.airbnb.com/rooms/8339  2.020000e+13     6/2/2019
# 8739    https://www.airbnb.com/rooms/8739  2.020000e+13     6/2/2019
# 9225    https://www.airbnb.com/rooms/9225  2.020000e+13     6/2/2019
# 10820  https://www.airbnb.com/rooms/10820  2.020000e+13     6/2/2019
# 10824  https://www.airbnb.com/rooms/10824  2.020000e+13     6/2/2019
# 10832  https://www.airbnb.com/rooms/10832  2.020000e+13     6/2/2019
# 12041  https://www.airbnb.com/rooms/12041  2.020000e+13     6/2/2019
#
#                                                     name  \
# id
# 958                  Bright, Modern Garden Unit - 1BR/1B
# 7918          A Friendly Room - UCSF/USF - San Francisco
# 8142   Friendly Room Apt. Style -UCSF/USF - San Franc...
# 8339                     Historic Alamo Square Victorian
# 8739                 Mission Sunshine, with Private Bath
# 9225           Artful Potrero Separate Floor with Garden
# 10820                 Haight Buena Vista Park Garden 3BR
# 10824         Victorian House in Hayes Valley - 3BED-2BA
# 10832                           Union Square Modern Loft
# 12041    Sunny/Sunset view room UCSF/USF - San Francisco
#
#                                                  summary  \
# id
# 958    New update: the house next door is under const...
# 7918   Nice and good public transportation.  7 minute...
# 8142   Nice and good public transportation.  7 minute...
# 8339   Pls email before booking.  Interior featured i...
# 8739   Welcome to The Mission, the sunniest neighborh...
# 9225   A Unique Guest Suite! A Spacious  Art Filled  ...
# 10820  This property is only available with a minimum...
# 10824  This property is only available with a minimum...
# 10832  This property is only available with a minimum...
# 12041  Nice and good public transportation.  7 minute...
#
#                                                    space  \
# id
# 958    Newly remodeled, modern, and bright garden uni...
# 7918   Room rental-sunny view room/sink/Wi Fi (inner ...
# 8142   Room rental Sunny view Rm/Wi-Fi/TV/sink/large ...
# 8339   Please send us a quick message before booking ...
# 8739   Your sunny room looks out over a lush garden, ...
# 9225   It is unique, very spacious  [800 sq. ft. with...
# 10820  PROPERTY DESCRIPTION  This historic 3 bedroom ...
# 10824  PROPERTY DESCRIPTION  This San Francisco Victo...
# 10832  PROPERTY DESCRIPTION  Where Culture Meets Cout...
# 12041  Settle down, S.F. resident, student, hospital,...
#
#                                              description experiences_offered  \
# id
# 958    New update: the house next door is under const...                none
# 7918   Nice and good public transportation.  7 minute...                none
# 8142   Nice and good public transportation.  7 minute...                none
# 8339   Pls email before booking.  Interior featured i...                none
# 8739   Welcome to The Mission, the sunniest neighborh...                none
# 9225   A Unique Guest Suite! A Spacious  Art Filled  ...                none
# 10820  This property is only available with a minimum...                none
# 10824  This property is only available with a minimum...                none
# 10832  This property is only available with a minimum...                none
# 12041  Nice and good public transportation.  7 minute...                none
#
#                                    neighborhood_overview  \
# id
# 958    *Quiet cul de sac in friendly neighborhood *St...
# 7918   Shopping old town, restaurants, McDonald, Whol...
# 8142                                                 NaN
# 8339                                                 NaN
# 8739   Located between Valencia Street and Dolores Pa...
# 9225   It is a distinct neighborhood, with easy acces...
# 10820  Neighborhood: HAIGHT ASHBURY This vacation ren...
# 10824  Neighborhood: HAYES VALLEY. This San Francisco...
# 10832  Neighborhood: DOWNTOWN. This spectacular unit ...
# 12041  Small shopping old town , Golden Gate Park.  O...
#
#                                                    notes  ...  \
# id                                                        ...
# 958    Due to the fact that we have children and a do...  ...
# 7918   Please email your picture id with print name (...  ...
# 8142   Please email your picture id with print name (...  ...
# 8339                       tax ID on file tax ID on file  ...
# 8739   We live in a dense, urban neighborhood, and ou...  ...
# 9225                                                 NaN  ...
# 10820                                                NaN  ...
# 10824                                                NaN  ...
# 10832                                                NaN  ...
# 12041  Please email your picture id with print name (...  ...
#
#       instant_bookable is_business_travel_ready          cancellation_policy  \
# id
# 958                  t                        f                     moderate
# 7918                 f                        f  strict_14_with_grace_period
# 8142                 f                        f  strict_14_with_grace_period
# 8339                 f                        f                     moderate
# 8739                 t                        f  strict_14_with_grace_period
# 9225                 f                        f  strict_14_with_grace_period
# 10820                f                        f  strict_14_with_grace_period
# 10824                f                        f  strict_14_with_grace_period
# 10832                f                        f  strict_14_with_grace_period
# 12041                f                        f  strict_14_with_grace_period
#
#       require_guest_profile_picture  require_guest_phone_verification  \
# id
# 958                               f                                 f
# 7918                              f                                 f
# 8142                              f                                 f
# 8339                              t                                 t
# 8739                              f                                 f
# 9225                              f                                 f
# 10820                             f                                 f
# 10824                             f                                 f
# 10832                             f                                 f
# 12041                             f                                 f
#
#        calculated_host_listings_count  \
# id
# 958                                 1
# 7918                                9
# 8142                                9
# 8339                                2
# 8739                                2
# 9225                                1
# 10820                              39
# 10824                              39
# 10832                              39
# 12041                               9
#
#       calculated_host_listings_count_entire_homes  \
# id
# 958                                             1
# 7918                                            0
# 8142                                            0
# 8339                                            2
# 8739                                            0
# 9225                                            0
# 10820                                          39
# 10824                                          39
# 10832                                          39
# 12041                                           0
#
#        calculated_host_listings_count_private_rooms  \
# id
# 958                                               0
# 7918                                              9
# 8142                                              9
# 8339                                              0
# 8739                                              2
# 9225                                              1
# 10820                                             0
# 10824                                             0
# 10832                                             0
# 12041                                             9
#
#        calculated_host_listings_count_shared_rooms reviews_per_month
# id
# 958                                              0              1.60
# 7918                                             0              0.14
# 8142                                             0              0.14
# 8339                                             0              0.23
# 8739                                             0              5.61
# 9225                                             0              4.07
# 10820                                            0              0.32
# 10824                                            0              0.16
# 10832                                            0              0.25
# 12041                                            0              0.06
#
# [10 rows x 105 columns]

# %%
ab_df.isna().sum()

#ab_df.columns.values.tolist()
# Out:
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# name                                               0
# summary                                            0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               1034
# Length: 105, dtype: int64

# %%
ab_df = pd.DataFrame(ab_df,columns=['reviews_per_month'])
ab_df.describe()
# Out:
#        reviews_per_month
# count        5087.000000
# mean            1.999341
# std             2.080989
# min             0.010000
# 25%             0.370000
# 50%             1.230000
# 75%             3.000000
# max            20.000000
