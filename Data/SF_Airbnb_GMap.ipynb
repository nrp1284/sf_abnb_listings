# %%
import pandas as pd
import gmaps
import requests



# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
file = "./Resources/listings_cleaned2.csv"

# %%
region_df = pd.read_csv(file)
region_df.head()
# Out:
#      id host_since  host_response_time host_response_rate  host_is_superhost  \
# 0   958    7/31/08  within a few hours               100%                  1
# 1  7918    6/17/09  within a few hours               100%                  0
# 2  8142    6/17/09  within a few hours               100%                  0
# 3  8339     7/2/09      within an hour               100%                  0
# 4  8739    1/27/09      within an hour               100%                  1
#
#    host_listings_count  host_total_listings_count  host_identity_verified  \
# 0                    1                          1                       1
# 1                   10                         10                       1
# 2                   10                         10                       1
# 3                    2                          2                       1
# 4                    2                          2                       0
#
#   neighbourhood_cleansed  zipcode  ...  review_scores_value  instant_bookable  \
# 0       Western Addition    94115  ...                  9.0                 1
# 1         Haight Ashbury    94117  ...                  8.0                 0
# 2         Haight Ashbury    94117  ...                  9.0                 0
# 3       Western Addition    94115  ...                  9.0                 0
# 4                Mission    94110  ...                 10.0                 1
#
#   calculated_host_listings_count calculated_host_listings_count_entire_homes  \
# 0                              1                                           1
# 1                              9                                           0
# 2                              9                                           0
# 3                              2                                           2
# 4                              2                                           0
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             9
# 2                                             9
# 3                                             0
# 4                                             2
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                            0               1.60
# 1                                            0               0.14
# 2                                            0               0.14
# 3                                            0               0.23
# 4                                            0               5.61
#
#    host_days_active  time_since_first_review  time_since_last_review
# 0              3958                 4+ years                      17
# 1              3637                 4+ years                     923
# 2              3637                 4+ years                     263
# 3              3622                 4+ years                     295
# 4              3778                 4+ years                      12
#
# [5 rows x 45 columns]

# %%
region_df.dtypes
# Out:
# id                                                int64
# host_since                                       object
# host_response_time                               object
# host_response_rate                               object
# host_is_superhost                                 int64
# host_listings_count                               int64
# host_total_listings_count                         int64
# host_identity_verified                            int64
# neighbourhood_cleansed                           object
# zipcode                                           int64
# latitude                                        float64
# longitude                                       float64
# property_type                                    object
# room_type                                        object
# accommodates                                      int64
# bathrooms                                       float64
# bedrooms                                          int64
# beds                                              int64
# price                                             int64
# minimum_nights                                    int64
# maximum_nights                                    int64
# calendar_updated                                 object
# availability_30                                   int64
# availability_60                                   int64
# availability_90                                   int64
# availability_365                                  int64
# number_of_reviews                                 int64
# number_of_reviews_ltm                             int64
# first_review                                     object
# review_scores_rating                            float64
# review_scores_accuracy                          float64
# review_scores_cleanliness                       float64
# review_scores_checkin                           float64
# review_scores_communication                     float64
# review_scores_location                          float64
# review_scores_value                             float64
# instant_bookable                                  int64
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# host_days_active                                  int64
# time_since_first_review                          object
# time_since_last_review                            int64
# dtype: object

# %%
# Filter hosts and
clean_df = region_df.loc[(region_df["host_response_rate"] == '100%') & 
                        (region_df['host_is_superhost'] == 1) &
                        (region_df['host_identity_verified'] == 1) &
                        (region_df['instant_bookable'] == 1) & 
                        # review ratings.
                        (region_df['review_scores_rating'] >= 80) & 
                        (region_df['review_scores_accuracy'] >= 7) & 
                        (region_df['review_scores_cleanliness'] >= 7) & 
                        (region_df['review_scores_checkin'] >= 7) & 
                        (region_df['review_scores_communication'] >= 7) & 
                        (region_df['review_scores_location'] >= 7) & 
                        (region_df['review_scores_value'] >= 7) &
                        # recent calendar updates.
                        (region_df['calendar_updated'] != '17 months ago') &
                        (region_df['calendar_updated'] != '14 months ago') &
                        (region_df['calendar_updated'] != '12 months ago')]
clean_df
# Out:
#           id host_since  host_response_time host_response_rate  \
# 0        958    7/31/08  within a few hours               100%
# 11     12522    5/22/09      within an hour               100%
# 18     23611    5/25/09      within an hour               100%
# 48     51557    9/16/10      within an hour               100%
# 58     59702   11/14/10      within an hour               100%
# ...      ...        ...                 ...                ...
# 9169  516836     6/4/12      within an hour               100%
# 9229  533627     6/4/12      within an hour               100%
# 9250  598271     6/4/12      within an hour               100%
# 9280  631658     6/4/12      within an hour               100%
# 9563  851889   12/19/12      within an hour               100%
#
#       host_is_superhost  host_listings_count  host_total_listings_count  \
# 0                     1                    1                          1
# 11                    1                    1                          1
# 18                    1                    3                          3
# 48                    1                    1                          1
# 58                    1                    1                          1
# ...                 ...                  ...                        ...
# 9169                  1                    9                          9
# 9229                  1                    9                          9
# 9250                  1                    9                          9
# 9280                  1                    9                          9
# 9563                  1                    1                          1
#
#       host_identity_verified neighbourhood_cleansed  zipcode  ...  \
# 0                          1       Western Addition    94115  ...
# 11                         1    Castro/Upper Market    94110  ...
# 18                         1         Bernal Heights    94110  ...
# 48                         1       Western Addition    94115  ...
# 58                         1         Bernal Heights    94110  ...
# ...                      ...                    ...      ...  ...
# 9169                       1           Potrero Hill    94107  ...
# 9229                       1           Potrero Hill    94107  ...
# 9250                       1           Potrero Hill    94107  ...
# 9280                       1           Potrero Hill    94107  ...
# 9563                       1        South of Market    94103  ...
#
#       review_scores_value  instant_bookable calculated_host_listings_count  \
# 0                     9.0                 1                              1
# 11                   10.0                 1                              1
# 18                   10.0                 1                              2
# 48                   10.0                 1                              1
# 58                   10.0                 1                              1
# ...                   ...               ...                            ...
# 9169                 10.0                 1                              4
# 9229                  9.0                 1                              4
# 9250                  9.0                 1                              4
# 9280                  9.0                 1                              4
# 9563                 10.0                 1                              1
#
#      calculated_host_listings_count_entire_homes  \
# 0                                              1
# 11                                             0
# 18                                             1
# 48                                             1
# 58                                             0
# ...                                          ...
# 9169                                           1
# 9229                                           1
# 9250                                           1
# 9280                                           1
# 9563                                           1
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 11                                               1
# 18                                               1
# 48                                               0
# 58                                               1
# ...                                            ...
# 9169                                             3
# 9229                                             3
# 9250                                             3
# 9280                                             3
# 9563                                             0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 0                                               0               1.60
# 11                                              0               3.48
# 18                                              0               2.17
# 48                                              0               1.00
# 58                                              0               1.93
# ...                                           ...                ...
# 9169                                            0               3.51
# 9229                                            0               0.30
# 9250                                            0               3.21
# 9280                                            0               0.42
# 9563                                            0               1.13
#
#       host_days_active  time_since_first_review  time_since_last_review
# 0                 3958                 4+ years                      17
# 11                3663                 4+ years                      18
# 18                3660                 4+ years                       9
# 48                3181                 4+ years                      78
# 58                3122                 4+ years                      30
# ...                ...                      ...                     ...
# 9169              2554                 4+ years                      25
# 9229              2554                 4+ years                     142
# 9250              2554                 4+ years                      17
# 9280              2554                 4+ years                       9
# 9563              2356                2-3 years                       7
#
# [497 rows x 45 columns]

# %%
clean_df.calendar_updated.value_counts()
# Out:
# today            108
# 2 weeks ago       86
# 3 weeks ago       37
# a week ago        35
# 4 days ago        27
# yesterday         26
# 4 weeks ago       24
# 2 months ago      21
# 5 days ago        19
# 3 days ago        19
# 5 weeks ago       19
# 6 days ago        13
# 6 weeks ago       12
# 7 weeks ago       12
# 2 days ago        10
# 1 week ago         9
# 3 months ago       7
# 7 months ago       3
# 4 months ago       3
# 10 months ago      2
# 5 months ago       2
# 11 months ago      1
# 8 months ago       1
# 6 months ago       1
# Name: calendar_updated, dtype: int64

# %%
# Ask the customer to add a minimum and maximum price value.
min_price = float(input("What is the minimum price you would like for your hotel? "))
max_price = float(input("What is the maximum price you would like for your hotel? "))
# Out:
# What is the minimum price you would like for your hotel? 10
# What is the maximum price you would like for your hotel? 100

# %%
# Filter the dataset to find the hotels that fit the criteria.
preferred_df = clean_df.loc[(clean_df["price"] <= max_price) & (clean_df["price"] >= min_price)]
preferred_df
# Out:
#             id host_since host_response_time host_response_rate  \
# 11       12522    5/22/09     within an hour               100%
# 18       23611    5/25/09     within an hour               100%
# 135     208727    4/19/11     within an hour               100%
# 157     256176    8/16/11     within an hour               100%
# 189     323635    7/12/11     within an hour               100%
# ...        ...        ...                ...                ...
# 4835  32210241    1/29/12     within an hour               100%
# 4894  32617586     3/4/13     within an hour               100%
# 4918  32724526    9/20/14     within an hour               100%
# 7119    810315   12/14/11     within an hour               100%
# 8871    651624    8/15/12     within an hour               100%
#
#       host_is_superhost  host_listings_count  host_total_listings_count  \
# 11                    1                    1                          1
# 18                    1                    3                          3
# 135                   1                    8                          8
# 157                   1                    1                          1
# 189                   1                    2                          2
# ...                 ...                  ...                        ...
# 4835                  1                    4                          4
# 4894                  1                    6                          6
# 4918                  1                    1                          1
# 7119                  1                    3                          3
# 8871                  1                    1                          1
#
#       host_identity_verified neighbourhood_cleansed  zipcode  ...  \
# 11                         1    Castro/Upper Market    94110  ...
# 18                         1         Bernal Heights    94110  ...
# 135                        1         Outer Richmond    94121  ...
# 157                        1         Inner Richmond    94118  ...
# 189                        1              Excelsior    94134  ...
# ...                      ...                    ...      ...  ...
# 4835                       1        Pacific Heights    94115  ...
# 4894                       1                Mission    94110  ...
# 4918                       1              Glen Park    94131  ...
# 7119                       1                 Marina    94123  ...
# 8871                       1          Outer Mission    94112  ...
#
#       review_scores_value  instant_bookable calculated_host_listings_count  \
# 11                   10.0                 1                              1
# 18                   10.0                 1                              2
# 135                   9.0                 1                              2
# 157                   9.0                 1                              1
# 189                  10.0                 1                              2
# ...                   ...               ...                            ...
# 4835                 10.0                 1                              3
# 4894                 10.0                 1                              5
# 4918                 10.0                 1                              1
# 7119                 10.0                 1                              2
# 8871                 10.0                 1                              1
#
#      calculated_host_listings_count_entire_homes  \
# 11                                             0
# 18                                             1
# 135                                            0
# 157                                            0
# 189                                            0
# ...                                          ...
# 4835                                           1
# 4894                                           0
# 4918                                           1
# 7119                                           0
# 8871                                           0
#
#       calculated_host_listings_count_private_rooms  \
# 11                                               1
# 18                                               1
# 135                                              2
# 157                                              1
# 189                                              2
# ...                                            ...
# 4835                                             2
# 4894                                             5
# 4918                                             0
# 7119                                             2
# 8871                                             1
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month  \
# 11                                              0               3.48
# 18                                              0               2.17
# 135                                             0               0.33
# 157                                             0               3.12
# 189                                             0               0.71
# ...                                           ...                ...
# 4835                                            0               2.06
# 4894                                            0               1.38
# 4918                                            0               5.29
# 7119                                            0               0.53
# 8871                                            0               1.78
#
#       host_days_active  time_since_first_review  time_since_last_review
# 11                3663                 4+ years                      18
# 18                3660                 4+ years                       9
# 135               2966                 4+ years                     265
# 157               2847                 4+ years                       4
# 189               2882                 4+ years                      42
# ...                ...                      ...                     ...
# 4835              2681               0-6 months                      20
# 4894              2281               0-6 months                      28
# 4918              1716               0-6 months                      10
# 7119              2727                2-3 years                     163
# 8871              2482                 4+ years                      12
#
# [113 rows x 45 columns]

# %%
# Create a descirption box.
info_box_template = """
<dl>
<dt>ID</dt><dd>{id}</dd>
<dt>Neighbourhood</dt><dd>{neighbourhood_cleansed}</dd>
<dt>Price</dt><dd>{price}</dd>
<dt>Rating</dt><dd>{review_scores_rating}</dd>
</dl>
"""

# Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in preferred_df.iterrows()]

# Get the latitude and longitude from each row and store in a new DataFrame.
locations = preferred_df[["latitude", "longitude"]]

# %%
# Assign the figure variable.
fig = gmaps.figure(center=(37.77, -122.4), zoom_level=11.8)

# Add a marker_layer.
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)

# Display.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
